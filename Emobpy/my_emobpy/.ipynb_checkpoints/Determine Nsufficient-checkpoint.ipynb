# %%
import os
import pandas as pd
from emobpy import DataBase
from emobpy import Mobility

# %%
ts_generation_path = os.getcwd()
os.chdir("../")
data_path = os.getcwd()
os.chdir(ts_generation_path)

path = os.getcwd()
consumption_path = os.path.join(path, "db", "consumption")
availability_path = os.path.join(path, "db", "availability")
profile_path  = os.path.join(path, "db", "profile")

DB = DataBase('db')
DB_consumption = DataBase("db/consumption")
DB_availability = DataBase("db/availability")
DB_profile = DataBase('db/profile')

# %% [markdown]
# #generate new profiles
#
# for i in range(1000):
#     try:
#         m = Mobility(config_folder='config_files')
#         m.set_params(
#                  name_prefix="BEV{}".format(i),
#                  total_hours=168,
#                  time_step_in_hrs=0.25, # 15 minutes
#                  category="user_defined",
#                  reference_date="01/01/2020"
#                 )
#         m.set_stats(
#                 stat_ntrip_path="TripsPerDay.csv",
#                 stat_dest_path="DepartureDestinationTrip.csv",
#                 stat_km_duration_path="DistanceDurationTrip.csv",
#                 )
#         m.set_rules(rule_key="user_defined")
#         # see /config_files/rules.yml, it contains a dictionary, whose key must be the same
#         # as rule_key. To see all possible rules `from emobpy.constants import RULE; RULE`
#         m.run()
#         m.save_profile(folder="db/profile", description='') # save all info in pickle file in 'db' folder
#
#     except ValueError:
#         pass
#
# DB_profile.update()                # This load new files hosted in database folder as result of new generated files

# %%
from emobpy import Consumption, HeatInsulation, BEVspecs
DB_profile.update()


mname = list(DB_profile.db.keys())     # getting the id of the first mobility profile
HI = HeatInsulation(True)            # Creating the heat insulation by copying the default configuration
BEVS = BEVspecs()                    # Database that contains BEV models


      #Choosing the models I want to assign to the profiles:
#Brand: model: Charging efficiency,year ##
models = {
    "Audi":{
        "e-tron 55 quattro": [(0.1, 2019), (0.2, 2020)],
        "e-tron 55 quattro Premium Plus": [(0.1, 2019)],
        "e-tron 55 quattro Prestige": [(0.1, 2019)],
        "e-tron Sportback 50 quattro": [(0.1, 2020)],
        "e-tron Sportback 55 quattro": [(0.1, 2020)]
    },
    "BMW":{"i3 22 kWh": [(0.1, 2014), (0.1, 2015), (0.1, 2016)],
           "i3 33 kWh": [(0.1, 2017), (0.1, 2018)],
           "i3 42 kWh": [(0.1, 2019)],
           "i3s 33 kWh": [(0.1, 2018)],
           "i3s 42 kWh": [(0.1, 2019)],
           "i3s Edition RoadStyle 42 kWh": [(0.1, 2020)]
    }
}

# %%
models_assigned = {}
# assign models to profiles
for brand in models.keys():
    models_assigned[brand] = {}
    for m in models[brand].keys():
        models_assigned[brand][m] = {}
        for (p, y) in models[brand][m]:
            models_assigned[brand][m][y] = (BEVS.model((brand,m,y)),p)

# %%
folder_size = 1000
folder_num = 0
consumption_path_new = os.path.join(consumption_path, f"{folder_num}")
DB_consumption.update()

#create consumption for every profile and respective car properties
for f, file in enumerate(mname):
    for brand in list(models_assigned.keys())[:1]:
        for m in list(models_assigned[brand].keys())[:1]:
            for y in list(models_assigned[brand][m].keys())[:1]:
                car_model = models_assigned[brand][m][y][0]
                
                if (f*3 > folder_size): ##allgemeine Regel aufschreiben 
                    folder_size += folder_size + 1000
                    consumption_path_new = os.path.join(consumption_path, f"{folder_num}")
                    os.makedirs(consumption_path_new, exist_ok=True)  # succeeds even if directory exists.
                    folder_num += 1
                    print(consumption_path_new)
                
                #for i in range(0, round(models_assigned[brand][m][y][1] * len(mname))):
                print(car_model)
                c = Consumption(file, car_model)
                c.load_setting_mobility(DB_profile)
                c.run(
                    heat_insulation=HI,
                    weather_country='DE',
                    weather_year=2016,
                    passenger_mass=75,                   # kg
                    passenger_sensible_heat=70,          # W
                    passenger_nr=1.5,                    # Passengers per vehicle including driver
                    air_cabin_heat_transfer_coef=20,     # W/(m2K). Interior walls
                    air_flow = 0.02,                     # m3/s. Ventilation
                    driving_cycle_type='WLTC',           # Two options "WLTC" or "EPA"
                    road_type=0,                         # For rolling resistance, Zero represents a new road.
                    road_slope=0
                )
                c.save_profile(consumption_path_new)
# Out:
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV316_W2_b1d38_Audi_e-tron_55_quattro_2019_a3bc8
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV112_W2_7da24_Audi_e-tron_55_quattro_2019_09cc0
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV232_W2_54106_Audi_e-tron_55_quattro_2019_f6148
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV97_W2_35eab_Audi_e-tron_55_quattro_2019_d5e0d
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV377_W2_8e6d8_Audi_e-tron_55_quattro_2019_942ad
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV16_W2_fb015_Audi_e-tron_55_quattro_2019_3e9bc
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV466_W2_d1dfe_Audi_e-tron_55_quattro_2019_2de93
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV305_W2_827f2_Audi_e-tron_55_quattro_2019_41b7f
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV633_W2_bb4a2_Audi_e-tron_55_quattro_2019_586b9
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV103_W2_a3ecd_Audi_e-tron_55_quattro_2019_6ac94
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV257_W2_c7871_Audi_e-tron_55_quattro_2019_f5d97
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV337_W2_33c69_Audi_e-tron_55_quattro_2019_20fd4
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [4 / 4] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV367_W2_9256a_Audi_e-tron_55_quattro_2019_6c49a
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV41_W2_0dfad_Audi_e-tron_55_quattro_2019_8a789
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [15 / 15] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV684_W2_a2c2d_Audi_e-tron_55_quattro_2019_9459a
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [4 / 4] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV28_W2_42c24_Audi_e-tron_55_quattro_2019_260bf
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV992_W2_9dc36_Audi_e-tron_55_quattro_2019_6bb35
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV459_W2_b35c8_Audi_e-tron_55_quattro_2019_6f21e
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV71_W2_ac9ad_Audi_e-tron_55_quattro_2019_9d22f
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [3 / 3] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV425_W2_5fa43_Audi_e-tron_55_quattro_2019_113ad
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [4 / 4] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV888_W2_90de8_Audi_e-tron_55_quattro_2019_ead0e
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [19 / 19] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV127_W2_3e252_Audi_e-tron_55_quattro_2019_b5371
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [12 / 12] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV31_W2_a34d7_Audi_e-tron_55_quattro_2019_681f3
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [12 / 12] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV25_W2_dad2f_Audi_e-tron_55_quattro_2019_4d309
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [17 / 17] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV164_W2_c7531_Audi_e-tron_55_quattro_2019_64a77
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV495_W2_5a456_Audi_e-tron_55_quattro_2019_9d598
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV181_W2_deb8a_Audi_e-tron_55_quattro_2019_0def2
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV228_W2_16d2d_Audi_e-tron_55_quattro_2019_2a535
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [5 / 5] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV304_W2_72151_Audi_e-tron_55_quattro_2019_7135d
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [12 / 12] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV245_W2_3803d_Audi_e-tron_55_quattro_2019_54a55
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [12 / 12] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV167_W2_20719_Audi_e-tron_55_quattro_2019_70e91
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [4 / 4] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV520_W2_b1892_Audi_e-tron_55_quattro_2019_1f6d7
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV153_W2_937af_Audi_e-tron_55_quattro_2019_632c4
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV520_W2_ef97c_Audi_e-tron_55_quattro_2019_7dcb3
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV133_W2_69145_Audi_e-tron_55_quattro_2019_1fc17
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [16 / 16] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV945_W2_37abf_Audi_e-tron_55_quattro_2019_59813
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [15 / 15] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV196_W2_bcb9a_Audi_e-tron_55_quattro_2019_522a3
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [2 / 2] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV270_W2_98272_Audi_e-tron_55_quattro_2019_7b436
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV359_W2_48f33_Audi_e-tron_55_quattro_2019_c4362
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV228_W2_b050b_Audi_e-tron_55_quattro_2019_9fd74
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV132_W2_4b727_Audi_e-tron_55_quattro_2019_b3fe2
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV782_W2_6571d_Audi_e-tron_55_quattro_2019_c286e
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV298_W2_1c78a_Audi_e-tron_55_quattro_2019_5e099
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV443_W2_7f0bb_Audi_e-tron_55_quattro_2019_be564
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV90_W2_cf976_Audi_e-tron_55_quattro_2019_7632a
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV58_W2_9ea03_Audi_e-tron_55_quattro_2019_03e09
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [17 / 17] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV249_W2_289c6_Audi_e-tron_55_quattro_2019_6f68d
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [15 / 15] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV446_W2_3c96f_Audi_e-tron_55_quattro_2019_290a5
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [25 / 25] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV297_W2_d1002_Audi_e-tron_55_quattro_2019_8fe8f
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV15_W2_61cfb_Audi_e-tron_55_quattro_2019_f4415
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV366_W2_75696_Audi_e-tron_55_quattro_2019_2f404
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV184_W2_a53e6_Audi_e-tron_55_quattro_2019_aa045
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [5 / 5] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV10_W2_b801d_Audi_e-tron_55_quattro_2019_009de
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV79_W2_32f50_Audi_e-tron_55_quattro_2019_23b90
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV211_W2_082fb_Audi_e-tron_55_quattro_2019_38c22
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV358_W2_3a3f5_Audi_e-tron_55_quattro_2019_e6ea6
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV328_W2_b723b_Audi_e-tron_55_quattro_2019_6b2b4
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV231_W2_43169_Audi_e-tron_55_quattro_2019_622f3
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [20 / 20] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV0_W2_fab45_Audi_e-tron_55_quattro_2019_9c3b0
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV951_W2_52f03_Audi_e-tron_55_quattro_2019_d5573
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [16 / 16] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV769_W2_ff8bd_Audi_e-tron_55_quattro_2019_ecd7d
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [12 / 12] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV500_W2_2fbac_Audi_e-tron_55_quattro_2019_3178d
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV602_W2_93028_Audi_e-tron_55_quattro_2019_18593
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV134_W2_081ff_Audi_e-tron_55_quattro_2019_8cdfb
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV336_W2_5099f_Audi_e-tron_55_quattro_2019_05217
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [17 / 17] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV308_W2_8b079_Audi_e-tron_55_quattro_2019_5c3a2
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [21 / 21] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV8_W2_7152a_Audi_e-tron_55_quattro_2019_ad4c8
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [2 / 2] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV478_W2_05a6c_Audi_e-tron_55_quattro_2019_54975
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV651_W2_b8939_Audi_e-tron_55_quattro_2019_cd246
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [5 / 5] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV380_W2_e2698_Audi_e-tron_55_quattro_2019_fdad5
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV265_W2_b94ee_Audi_e-tron_55_quattro_2019_6e5f8
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV211_W2_13ad6_Audi_e-tron_55_quattro_2019_5a9b0
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [4 / 4] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV186_W2_55bf6_Audi_e-tron_55_quattro_2019_d371c
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [28 / 28] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV317_W2_f97b3_Audi_e-tron_55_quattro_2019_298e9
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [15 / 15] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV384_W2_02c19_Audi_e-tron_55_quattro_2019_eb584
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV349_W2_4705c_Audi_e-tron_55_quattro_2019_fa8ec
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [12 / 12] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV190_W2_4721d_Audi_e-tron_55_quattro_2019_86023
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV152_W2_9dd80_Audi_e-tron_55_quattro_2019_c2702
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV679_W2_a82b4_Audi_e-tron_55_quattro_2019_41e45
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV94_W2_ecafe_Audi_e-tron_55_quattro_2019_a9170
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV23_W2_c0fdd_Audi_e-tron_55_quattro_2019_8335d
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [25 / 25] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV103_W2_7f91c_Audi_e-tron_55_quattro_2019_4e3ad
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [23 / 23] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV325_W2_58096_Audi_e-tron_55_quattro_2019_8dca5
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV3_W2_ddf34_Audi_e-tron_55_quattro_2019_d9d38
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [12 / 12] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV167_W2_41393_Audi_e-tron_55_quattro_2019_c8c0d
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [20 / 20] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV448_W2_51b95_Audi_e-tron_55_quattro_2019_772fd
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [15 / 15] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV24_W2_d5cbe_Audi_e-tron_55_quattro_2019_f7567
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV17_W2_267f2_Audi_e-tron_55_quattro_2019_b69a6
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [22 / 22] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV1_W2_3f35f_Audi_e-tron_55_quattro_2019_06bb7
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [4 / 4] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV181_W2_42aec_Audi_e-tron_55_quattro_2019_c90b0
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV55_W2_d926e_Audi_e-tron_55_quattro_2019_e4683
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV730_W2_88044_Audi_e-tron_55_quattro_2019_baf68
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [17 / 17] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV236_W2_a70d2_Audi_e-tron_55_quattro_2019_7fc10
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [17 / 17] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV40_W2_3dd8e_Audi_e-tron_55_quattro_2019_21255
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV26_W2_249f9_Audi_e-tron_55_quattro_2019_f4b30
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [4 / 4] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV11_W2_7d180_Audi_e-tron_55_quattro_2019_08a6a
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV257_W2_a0411_Audi_e-tron_55_quattro_2019_84f96
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [16 / 16] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV384_W2_89079_Audi_e-tron_55_quattro_2019_18207
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV481_W2_91f0b_Audi_e-tron_55_quattro_2019_7c561
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV166_W2_ad1fd_Audi_e-tron_55_quattro_2019_fad37
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV63_W2_cc719_Audi_e-tron_55_quattro_2019_66b07
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [6 / 6] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV405_W2_2cc86_Audi_e-tron_55_quattro_2019_e008c
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [16 / 16] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV145_W2_c8b65_Audi_e-tron_55_quattro_2019_760fb
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [21 / 21] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV51_W2_2f33a_Audi_e-tron_55_quattro_2019_15d8b
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV14_W2_0c16f_Audi_e-tron_55_quattro_2019_2e6ac
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [16 / 16] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV844_W2_543d7_Audi_e-tron_55_quattro_2019_a85b1
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# ...
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV325_W2_8e9ba_Audi_e-tron_55_quattro_2019_e25d0
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV779_W2_4e484_Audi_e-tron_55_quattro_2019_c6ed6
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV93_W2_bc5c0_Audi_e-tron_55_quattro_2019_41b43
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV151_W2_735b4_Audi_e-tron_55_quattro_2019_46135
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV786_W2_1cc43_Audi_e-tron_55_quattro_2019_1c4e5
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV110_W2_9dc28_Audi_e-tron_55_quattro_2019_a4a93
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [9 / 9] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV7_W2_fb6c2_Audi_e-tron_55_quattro_2019_bb767
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV499_W2_10db2_Audi_e-tron_55_quattro_2019_35347
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV330_W2_ff5d5_Audi_e-tron_55_quattro_2019_3cc53
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [17 / 17] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV256_W2_53ee8_Audi_e-tron_55_quattro_2019_7b3de
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [18 / 18] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV205_W2_47b81_Audi_e-tron_55_quattro_2019_32a1c
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [2 / 2] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV527_W2_f6962_Audi_e-tron_55_quattro_2019_73fed
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV485_W2_4b4de_Audi_e-tron_55_quattro_2019_d6945
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [17 / 17] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV234_W2_b80c7_Audi_e-tron_55_quattro_2019_40061
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [20 / 20] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV76_W2_d07eb_Audi_e-tron_55_quattro_2019_f0313
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV343_W2_55564_Audi_e-tron_55_quattro_2019_a07c4
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV473_W2_13f95_Audi_e-tron_55_quattro_2019_edc6c
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV256_W2_cc087_Audi_e-tron_55_quattro_2019_4069b
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV428_W2_15ea7_Audi_e-tron_55_quattro_2019_c127c
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV613_W2_693d7_Audi_e-tron_55_quattro_2019_f86f2
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV325_W2_ded2b_Audi_e-tron_55_quattro_2019_893d0
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV235_W2_99211_Audi_e-tron_55_quattro_2019_3ac7a
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV22_W2_2bcc9_Audi_e-tron_55_quattro_2019_4d119
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [20 / 20] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV924_W2_0dcc7_Audi_e-tron_55_quattro_2019_6f3d8
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV608_W2_63045_Audi_e-tron_55_quattro_2019_85a4a
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV255_W2_86138_Audi_e-tron_55_quattro_2019_d6d85
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [19 / 19] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV610_W2_26e7e_Audi_e-tron_55_quattro_2019_b2067
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV177_W2_2c668_Audi_e-tron_55_quattro_2019_7cc16
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [8 / 8] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV284_W2_5c573_Audi_e-tron_55_quattro_2019_e7b36
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [7 / 7] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV434_W2_f69ec_Audi_e-tron_55_quattro_2019_25bee
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [13 / 13] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV159_W2_a27d6_Audi_e-tron_55_quattro_2019_a8f09
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [10 / 10] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV351_W2_6c280_Audi_e-tron_55_quattro_2019_b6a19
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [11 / 11] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV292_W2_4ebe3_Audi_e-tron_55_quattro_2019_c3f71
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [22 / 22] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV623_W2_d5c3b_Audi_e-tron_55_quattro_2019_9d895
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [14 / 14] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log
# <emobpy.consumption.ModelSpecs object at 0x7fe31daf1828>
# New profile running: BEV80_W2_ff558_Audi_e-tron_55_quattro_2019_dee9a
# temp Kelvin DE 2016 Timezone: Europe/Berlin
# pressure Pascal DE 2016 Timezone: Europe/Berlin
# dew_point Kelvin DE 2016 Timezone: Europe/Berlin
# Progress: 100% [15 / 15] trips
#
# See Log files
# /Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/log/emobpy.log

# %%
DB_profile.loadfiles()

pnames = list(DB_profile.db.keys())

# %%
len(pnames)
# Out:
# 3311

# %%
#analyse already existing profiles
os.listdir(consumption_path)
# Out:
# ['.DS_Store', '0', '1']

# %%
profile = DB.db[c_file]

# %%
c = profile["brand"]+"_" +profile["model"]+"_" +profile["year"]

# %%
a = profile["timeseries"]["consumption"].to_frame().rename(
                columns={"consumption":c})

# %%
consumption_df
# Out:
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      ...  Audi/e-tron_55_quattro/2019  \
# date                 ...
# 2020-01-01 00:00:00  ...                          0.0
# 2020-01-01 00:15:00  ...                          0.0
# 2020-01-01 00:30:00  ...                          0.0
# 2020-01-01 00:45:00  ...                          0.0
# 2020-01-01 01:00:00  ...                          0.0
# ...                  ...                          ...
# 2020-01-07 22:45:00  ...                          0.0
# 2020-01-07 23:00:00  ...                          0.0
# 2020-01-07 23:15:00  ...                          0.0
# 2020-01-07 23:30:00  ...                          0.0
# 2020-01-07 23:45:00  ...                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019
# date
# 2020-01-01 00:00:00                          0.0
# 2020-01-01 00:15:00                          0.0
# 2020-01-01 00:30:00                          0.0
# 2020-01-01 00:45:00                          0.0
# 2020-01-01 01:00:00                          0.0
# ...                                          ...
# 2020-01-07 22:45:00                          0.0
# 2020-01-07 23:00:00                          0.0
# 2020-01-07 23:15:00                          0.0
# 2020-01-07 23:30:00                          0.0
# 2020-01-07 23:45:00                          0.0
#
# [672 rows x 1415 columns]

# %%
pd.concat([consumption_df, a], axis=1)
# Out:
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      ...  Audi/e-tron_55_quattro/2019  \
# date                 ...
# 2020-01-01 00:00:00  ...                          0.0
# 2020-01-01 00:15:00  ...                          0.0
# 2020-01-01 00:30:00  ...                          0.0
# 2020-01-01 00:45:00  ...                          0.0
# 2020-01-01 01:00:00  ...                          0.0
# ...                  ...                          ...
# 2020-01-07 22:45:00  ...                          0.0
# 2020-01-07 23:00:00  ...                          0.0
# 2020-01-07 23:15:00  ...                          0.0
# 2020-01-07 23:30:00  ...                          0.0
# 2020-01-07 23:45:00  ...                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi/e-tron_55_quattro/2019  Audi/e-tron_55_quattro/2019  \
# date
# 2020-01-01 00:00:00                          0.0                          0.0
# 2020-01-01 00:15:00                          0.0                          0.0
# 2020-01-01 00:30:00                          0.0                          0.0
# 2020-01-01 00:45:00                          0.0                          0.0
# 2020-01-01 01:00:00                          0.0                          0.0
# ...                                          ...                          ...
# 2020-01-07 22:45:00                          0.0                          0.0
# 2020-01-07 23:00:00                          0.0                          0.0
# 2020-01-07 23:15:00                          0.0                          0.0
# 2020-01-07 23:30:00                          0.0                          0.0
# 2020-01-07 23:45:00                          0.0                          0.0
#
#                      Audi_e-tron_55_quattro_2019
# date
# 2020-01-01 00:00:00                          0.0
# 2020-01-01 00:15:00                          0.0
# 2020-01-01 00:30:00                          0.0
# 2020-01-01 00:45:00                          0.0
# 2020-01-01 01:00:00                          0.0
# ...                                          ...
# 2020-01-07 22:45:00                          0.0
# 2020-01-07 23:00:00                          0.0
# 2020-01-07 23:15:00                          0.0
# 2020-01-07 23:30:00                          0.0
# 2020-01-07 23:45:00                          0.0
#
# [672 rows x 1416 columns]

# %%
    #get consumption_ts, name
    for c_file in cnames:
        profile = DB.db[c_file]
        try:
            col_name = profile["brand"]+"_" +profile["model"]+"_" +profile["year"]
            consumption = profile["timeseries"]["consumption"].to_frame().rename(
                columns={"consumption":col_name})
            consumption_df = pd.concat([consumption_df, consumption], axis=1)
        except KeyError:
            print(c_file)
            pass
# Out:
# '/Users/Jarusch/Documents/Hertie/Hertie School/OneDrive - Hertie School/Jarusch/Virtual_storage/Modelling/Emobpy/my_emobpy/db/1'

# %%
consumption_df = pd.DataFrame()

for folder in os.listdir(consumption_path)[1:]:
    DB = DataBase(os.path.join(path, "db", "consumption", folder))
    DB.update()
    DB.loadfiles()
    cnames = list(DB.db.keys()) 
    print(len(cnames))
    
    #get consumption_ts, name
    for c_file in cnames:
        profile = DB.db[c_file]
        try:
            col_name = profile["brand"]+"/" +profile["model"]+"/" +profile["year"]
            consumption = profile["timeseries"]["consumption"].to_frame().rename(
                columns={"consumption":col_name})
            consumption_df = pd.concat([consumption_df, consumption], axis=1)
        except KeyError:
            print(c_file)
            pass
# Out:
# 3000
# 311

# %%
reduced = consumption_df.dropna()

# %%
n_max = reduced.shape[1]

# %%
n_max
# Out:
# 3311

# %%
#!pip install sklearn

# %%
from sklearn.metrics import mean_squared_error 
import matplotlib.pyplot as plt

# %%
rmse = {}

for sample_size in range(10, n_max): 
    Y_true = reduced.mean(1)
    Y_pred = reduced.iloc[:,:sample_size].mean(1)
    rmse[f'{sample_size}'] = mean_squared_error(Y_true,Y_pred, squared=False)

# %%
plt.scatter(range(10, n_max), rmse.values())
plt.xlabel("sample_size")
plt.ylabel("RMSE")
plt.ylim(0)
plt.show()

# %% [markdown]
# fig, ax = plt.subplots(len(range(0,n_max))):
#     for i in len(range(0,n_max)):
#         ax[i].plot(level_index[:], solution_dict[car]["m_late"]["level"][:])
#         ax[i].set_ylim(0, solution_dict[car]["m_early"]["level"].max())
#         ax[i].set_title("late_level")

# %%
rmse
# Out:
# {}
