# %% [markdown]
# https://stackoverflow.com/questions/53838696/problems-regarding-pyomo-provided-math-functions
#
# https://stackoverflow.com/questions/70048818/optimization-of-a-battery-storage-with-pyomo
#
# https://gitlab.com/diw-evu/emobpy/emobpy/-/blob/master/emobpy/data/evspecs.json
#
# https://github.com/L-Strobel/jointAnalysisCharging/tree/main/chargingmodel

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt#
import matplotlib.axes as axes
import pyomo.environ as pyo 
import pyomo.opt as opt
from IPython.display import clear_output
from pyomo.opt import SolverFactory
import random
from pandas import Timestamp
import pickle
import matplotlib.dates as mdates

# %% [markdown]
# ## Data input

# %%
V2G = False
short_or_long = "medium" #short: short, medium, long
flex = "constrained" #constrained meaning that late charging cannot be applied to the fullest extent
soc_min = 0 #level that should preferably be reached as soon as possible

# %%
#emobpy import
processing_path = os.getcwd()
os.chdir(f"/Users/Jarusch/Documents/EES/{short_or_long}")
    #f"../emobpy/{s hort_or_long}")

data_path = os.getcwd()
os.chdir(processing_path)
pics = os.path.join(processing_path, "Pictures","V2G" if V2G else "G2V", short_or_long)
if soc_min >0: 
    os.makedirs(os.path.join(processing_path, "Pictures", f"{soc_min}"), exist_ok = True)
    pics = os.path.join(processing_path, "Pictures", f"{soc_min}")

pics_input = os.path.join(pics, "input")

    

consumption_ts = pd.read_pickle(os.path.join(data_path,  "consumption"))
#consumption_ts = consumption_ts*100 
availability_ts = pd.read_pickle(os.path.join(data_path, "availability"))
car_properties_raw = pd.read_pickle(os.path.join(data_path,  "properties"))

# %%
profiles = min(consumption_ts.shape[1], availability_ts.shape[1], car_properties_raw.shape[1])


time_steps = len(availability_ts.dropna().index)

# %%
car_properties_raw.iloc[0] = 1
car_properties_raw.iloc[1] = 1

# %%
car_properties_raw.loc["battery_capacity"].mean()
# Out:
# 54.938675998393386

# %%
#consumption = pd.DataFrame(data = np.array([[0, 0.5], [0, 0.5], [0.5, 0], [0.5, 0]]), columns = ["c_1[kW]", "c_2[kW]"])
#power = pd.DataFrame(pd.DataFrame(data = np.array([[1, 0], [1, 0], [0, 1], [0, 1]]), columns = ["p_1 [kW]", "p_2 [kW]"]))

#kWh / timestep
#consumption_raw, power_raw, car_properties_raw = consumption_ts.iloc[:time_steps, :profiles].resample("h").mean(), availability_ts.iloc[:time_steps, :profiles].resample("h").mean(), car_properties_raw.iloc[:, :profiles]
consumption_raw, power_raw, car_properties_raw = consumption_ts, availability_ts, car_properties_raw

# %%
time_steps = len(power_raw.dropna().index)
consumption_raw, power_raw, car_properties_raw = consumption_raw.iloc[:time_steps, :profiles].dropna(), power_raw.iloc[:time_steps, :profiles].dropna(), car_properties_raw.iloc[:,:profiles].dropna()
neg_power_magnitude_raw = power_raw

#set datetime indexes 
index = consumption_raw.index[:time_steps]
consumption_raw.index, power_raw.index, neg_power_magnitude_raw.index = index, index, index

# %%
index
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:30:00',
#                '2020-01-01 01:00:00', '2020-01-01 01:30:00',
#                '2020-01-01 02:00:00', '2020-01-01 02:30:00',
#                '2020-01-01 03:00:00', '2020-01-01 03:30:00',
#                '2020-01-01 04:00:00', '2020-01-01 04:30:00',
#                ...
#                '2020-03-30 19:00:00', '2020-03-30 19:30:00',
#                '2020-03-30 20:00:00', '2020-03-30 20:30:00',
#                '2020-03-30 21:00:00', '2020-03-30 21:30:00',
#                '2020-03-30 22:00:00', '2020-03-30 22:30:00',
#                '2020-03-30 23:00:00', '2020-03-30 23:30:00'],
#               dtype='datetime64[ns]', name='date', length=4320, freq='30T')

# %% [markdown]
# ## Data plausibility

# %%
scale = 15/consumption_raw.shape[1] #15 mio EVs in GW

# %%
l= [consumption_raw.iloc[768:820].sum(1)/500000, consumption_raw.iloc[768:820, 950:1000].sum(1)/30]
df = pd.concat(l, axis =1, keys=["12000 profiles", "100 profiles"])
df.plot(ylim=(0), ylabel="consumption [kW/EV]")

# %%
pd.concat([
    consumption_raw.mean(1).resample("h").mean().resample("D").sum(), consumption_raw.mean(1).resample("h").sum().resample("D").sum()
], axis=1).plot()

# %%
#average consumption of 200Wh per km  https://de.statista.com/statistik/daten/studie/183003/umfrage/pkw---gefahrene-kilometer-pro-jahr/, https://ev-database.de/cheatsheet/energy-consumption-electric-car 
#median in Germany is at about 11000 km per year
con = consumption_raw.resample("h").mean().resample("D").sum().mean(0).mean()
specific_consumption = 0.2 #for consumtion [kWh]  / [kWh/km]  = km

plot = plt.bar(
    ["emobpy sampling", "statista (2021)"], [con*365/specific_consumption/100000, 14]
       )
plt.ylabel("1,000 km / year")
plt.tight_layout()

plt.savefig('annual_mileage.png',bbox_inches = "tight")

# %%
np.unique(power_raw.values)

# %%
#flexibility only available at home or at workplace 
flex_dict = {
    3.33 : {
        "time_steps" : 1    
    }
}
flex_dict[3.33]
# Out:
# {'time_steps': 1}

# %%
week_list = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
def groupby_weekday(df):
    return df.groupby(df.index.day_name()).sum().reindex(week_list)

# %%
#power ratings are mostly between 3 and 20 kW 
if soc_min ==0:  
    ts = power_raw.loc[(index.day<=7) & (index.month==1)].resample("D").mean()
    ts = ts.groupby(ts.index.day_name()).sum().reindex(week_list) 
    
    fig, ax = plt.subplots(figsize=(8, 3.5))
    ax.boxplot(
        ts.transpose(), labels= ts.index,
          )

    plt.ylabel('power rating [kW]')

    fig.tight_layout()
    #plt.savefig(os.path.join(pics_input, 'average_power_rating.png'), bbox_inches = "tight")

# %% [markdown]
# #power ratings are mostly between 3 and 20 kW
# if soc_min ==0:
#     ts = power_raw.loc[(index.day<=7) & (index.month==1)].resample("12h").mean()
#     fig, ax = plt.subplots(figsize=(8, 3.5))
#     ax.boxplot(
#         ts.transpose(), labels= [d[:3] + "/" + str(h) for d, h in zip(ts.index.day_name(), ts.index.hour)],
#           )
#
#     plt.ylabel('power rating [kW]')
#
#     fig.tight_layout()
#     plt.savefig(os.path.join(pics_input, 'average_power_rating.png'), bbox_inches = "tight")

# %%
df = pd.concat([power_raw.mean(1), consumption_raw.mean(1)/100], axis=1, keys=["grid_availability", "consumption"] )

# %%
consumption_raw.resample("h").mean().resample("D").sum().mean(1).resample("w").mean().plot()

# %%
ts =  (consumption_raw.mean(1)/100).resample("H").mean()

# %%
ts.resample("D").sum().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
ts =  (consumption_raw.mean(1)/100).resample("H").mean()
ts = ts[(ts.index.day >5)&(ts.index.day <13) & (ts.index.month ==1)]


fig, ax = plt.subplots(figsize=(8, 3.5))
ax.plot(ts.index, ts)
ax.xaxis.set_major_locator(mdates.DayLocator(interval = 1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))

ax.set_ylabel("power consumption [kW/EV]")
ax.grid('on', which='minor', axis='x', alpha=0.3)
ax.grid('on', which='major' )
ax.set_xlim(ts.index[0],ts.index[-1])
ax.set_ylim(0)
#ax.legend(list(ts.columns))

plt.savefig("consumtion_power_availability.png", bbox_inches = "tight")

# %%
station_dict = {0.0 : "none",
               3.33 : "home",
               19.8: "public"}
color_dict = {0.0 : "orange",
               3.33 : "green",
               19.8: "#0000FF"}
rating_weighted = False

p = power_raw
t = p.resample("H").ffill()
ts = t
ts = ts[(ts.index.day >5)&(ts.index.day <13) & (ts.index.month ==1)]

# %%
fig, ax = plt.subplots(figsize=(8, 3.5))
i = 0
bottom = 0
if rating_weighted == True: 
    n = ts[ts==3.33].count(1)*3.33 + ts[ts==19.8].count(1)*19.8

for r in np.unique(ts.values):
    if rating_weighted == True: 
        next_bottom = bottom+ts[ts==r].count(1)*r /n

    else: 
        next_bottom = bottom+ts[ts==r].count(1) / ts.shape[1]

    if (rating_weighted == True) &(r==0):
        continue
    else:
        plt.fill_between(x = ts.index,
            y1 = bottom,
            y2 = next_bottom,
            #alpha = 0.5,
            label = station_dict[r],
            facecolor = color_dict[r])
    bottom = next_bottom
    
    

ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))
plt.ylabel("power availability share [-]")
plt.ylim(0,1)
plt.xlim(ts.index[0],ts.index[-1])
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.5))
plt.grid()
ax.set_xlabel("January, 2020")
plt.savefig(f"availability_shares_weighted_{str(rating_weighted)}",bbox_inches = "tight" )

# %%
home_share_events = power_raw[power_raw==3.33].count().sum() / power_raw[power_raw>0].count().sum()
home_share_rating = power_raw[power_raw==3.33].sum().sum() / power_raw.sum().sum()


plt.bar(
    ["number of charging events", "power rating-weighted"], [home_share_events, home_share_rating]
     , label = "home", color = "green")
plt.bar(
    ["number of charging events", "power rating-weighted"], [1-home_share_events, 1-home_share_rating]
       , bottom = [home_share_events, home_share_rating], label = "public", color = "#0000FF")
plt.ylabel("home charging share [-]")
plt.legend()
plt.tight_layout()

plt.savefig('home_charging_shares.png',bbox_inches = "tight")

# %%
#https://www.agora-energiewende.de/en/service/recent-electricity-data/chart/power_generation/08.08.2021/08.08.2022/today/
german_peak = 73.3 #GW 30.11.2021
national_fleet_size = 10**6
scaling = national_fleet_size / consumption_raw.shape[0]
peak_load = consumption_raw.sum(1).nlargest(1).sum() #kW
print(peak_load) #kW 
print(peak_load*scaling*10**(-3) / german_peak) #kW --> GW

# %%
#plausibility:
#is the sum of the highest 10 consumption value assumed for one hour as constant lower than the average battery size?
(consumption_raw).mean(1).nlargest(10).sum() / car_properties_raw.iloc[2].mean()

# %%
consumption_raw.resample("H").mean().sum().sum()*4*1e-9*1e5 #annual demand in TWh #Korrekturfaktor = genau die 100!
#power_raw.resample("H").mean().sum().max()*1e-6*1e5 #annual demand in GW

# %% [markdown]
# # EES-transformation: Generating uncontrolled and latest charging ts

# %%
#set same names for columns
power_raw.columns = consumption_raw.columns
neg_power_magnitude_raw.columns = consumption_raw.columns
car_properties_raw.columns = consumption_raw.columns

# %%
solution_dict = {}
ees_constraints= pd.DataFrame()
M = 10000
failed_profiles = []

count = 0
count_failed = 0
for car in consumption_raw.columns.unique():
    try: 
        car_list = consumption_raw[car].columns
    except AttributeError as a:
        car_list = [car]

    for i, c in enumerate(car_list):
        print(count)
        if count <= 1000000:
            if type(consumption_raw[c]) == pd.core.series.Series:
                consumption = consumption_raw[c]
                power = power_raw[car]
                neg_power_magnitude = neg_power_magnitude_raw[c]
                car_properties = car_properties_raw[c]

            else: 
                consumption = consumption_raw[c].iloc[:,i]
                power= power_raw[car].iloc[:,i]
                neg_power_magnitude= neg_power_magnitude_raw[c].iloc[:,i]
                car_properties= car_properties_raw[c].iloc[:,i]


            
            battery_capacity = car_properties.loc["battery_capacity"]
            level_0 = car_properties["soc_init"]*battery_capacity
            level_T = car_properties.loc["soc_end"]*battery_capacity

            for model_type in ["m_early", "m_late"]:
                if (model_type == "m_late") & (car+str(i) in failed_profiles): 
                    pass
                else:
                    #Initialize model
                    m = pyo.ConcreteModel()

                    #initialize sets
                    m.t = pyo.Set(initialize = index, ordered = True)

                    #Initialize parameter
                    m.consumption = pyo.Param(m.t, initialize=consumption.to_dict())
                    m.power = pyo.Param(m.t, initialize=power.to_dict()) 
                    m.neg_power = pyo.Param(m.t, initialize=neg_power_magnitude.to_dict()) 

                    #Initialize variables
                    m.CHARGE = pyo.Var(m.t, within = pyo.NonNegativeReals)
                    m.SLACK = pyo.Var(m.t, within = pyo.NonNegativeReals)
                    m.DISCHARGE = pyo.Var(m.t, within = pyo.NonNegativeReals)
                    m.LEVEL = pyo.Var(m.t, within = pyo.NonNegativeReals, 
                                      bounds = (0,battery_capacity))

                    if ((model_type == "m_late") & (flex=="constrained")): ###
                        con = consumption_raw[car].iloc[:, i]
                        ava = power_raw[car].iloc[:, i]

                        public_index = ava[(ava!=3.33)].index
                        dep_home_index = con[((con==0) & (con.shift(-1) > 0) == True) & (ava==3.33)].index

                        m.t_pub = pyo.Set(initialize = public_index, ordered = True)
                        m.t_dep_home = pyo.Set(initialize = dep_home_index, ordered = True)

                        def full_before_next_trip(m, t_dep): ####
                            if t_dep in  index[:2]:
                                return pyo.Constraint.Skip
                            else:
                                t_dep_1 = pd.Timestamp(t_dep) - pd.Timedelta(index.freq)
                                return m.LEVEL[t_dep_1] >= solution_dict[car+str(i)]["m_early"]["level"].loc[t_dep_1]
                        m.Full_before_next_trip = pyo.Constraint(m.t_dep_home, rule=full_before_next_trip)

                        def public_uncontrolled(m, t_pub):  
                            return m.LEVEL[t_pub] == solution_dict[car+str(i)]["m_early"]["level"].loc[t_pub]
                        m.Public_uncontrolled = pyo.Constraint(m.t_pub, rule=public_uncontrolled)

                    #level constraints
                    def recursive_level(m, t):
                        if t == index[0]:
                            return m.LEVEL[t] == level_0 + (m.CHARGE[t] - m.DISCHARGE[t] - m.consumption[t] )
                        else:    
                            return m.LEVEL[t] == m.LEVEL[pd.Timestamp(t) - 
                                                             pd.Timedelta(index.freq)] + (
                                m.CHARGE[t] - m.DISCHARGE[t] - m.consumption[t] )   
                    m.Recursive_level = pyo.Constraint(m.t, rule = recursive_level)

                    def final_level(m, t):
                        if t == index[-1]:
                            return m.LEVEL[t] == level_T
                        else: 
                            return pyo.Constraint.Skip
                    m.Final_level = pyo.Constraint(m.t, rule=final_level)

                    #bidirectional charging 
                    def neg_power_min(m, t):
                        if V2G == True:
                            return m.DISCHARGE[t] <= m.neg_power[t] 
                        else:
                            return m.DISCHARGE[t] ==0
                    m.Neg_power_min_restriction = pyo.Constraint(m.t, rule=neg_power_min)

                    def power_max(m, t):
                        return m.CHARGE[t] <= m.power[t]   
                    m.Power_max_restriction = pyo.Constraint(m.t, rule=power_max)

                    def avoid_min_level(m, t):
                        return m.LEVEL[t] + m.SLACK[t] >= battery_capacity*soc_min
                    m.Avoid_min_level = pyo.Constraint(m.t, rule=avoid_min_level)

                    def battery_level_sum(m, t):    
                        if model_type == "m_late":
                            return sum(m.LEVEL[t] + M * m.SLACK[t] for t in m.t) 
                        else:
                            return sum(m.LEVEL[t] for t in m.t) 
                    if model_type == "m_late": sense = pyo.minimize
                    else: sense = pyo.maximize


                    m.Obj = pyo.Objective(rule=battery_level_sum, sense=sense)

                    #find solver
                    solvername='glpk'

                    #prepare solver
                    optimizer = opt.SolverFactory(solvername) 
                    solved_model = optimizer.solve(m)      ##tee=True   

                    if pd.DataFrame.from_dict(m.LEVEL.extract_values(), orient='index')[0][-1]== None:
                        failed_profiles.append(car+str(i))
                        print("failed")
                        count_failed += 1
                    else:    
                        print("succeeded")
                        level_series = pd.concat([
                            pd.Series(0, index=[index[0]-pd.Timedelta("1h")]),
                            pd.DataFrame.from_dict(m.LEVEL.extract_values(), orient='index')[0]
                        ], axis=0)
                        charge_df = pd.DataFrame.from_dict(m.CHARGE.extract_values(), orient='index', columns = [car])
                        discharge_df = pd.DataFrame.from_dict(m.DISCHARGE.extract_values(), orient='index', columns = [car])
                        
        
                        #store data in dictionary
                        if model_type == "m_early":
                            solution_dict[car+str(i)] = {}
                        solution_dict[car+str(i)][model_type] = {}
                        solution_dict[car+str(i)][model_type]["level"] = level_series
                        solution_dict[car+str(i)][model_type]["charge"] = charge_df
                        solution_dict[car+str(i)][model_type]["discharge"] = discharge_df
                        if model_type == "m_late":
                            count += 1 
solution_dict["failed_profiles"] = failed_profiles
# Out:
# 0
# failed
# 0
# failed
# 0
# failed
# 0
# failed
# 0
# failed
# 0
# failed
# 0
# failed
# 0
# failed
# 0
# succeeded
# succeeded
# 1
# failed
# 1
# failed
# 1
# failed
# 1
# failed
# 1
# failed
# 1
# succeeded
# succeeded
# 2
# failed
# 2
# failed
# 2
# failed
# 2
# failed
# 2
# failed
# 2
# failed
# 2
# failed
# 2
# failed
# 2
# succeeded
# succeeded
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# failed
# 3
# succeeded
# succeeded
# 4
# failed
# 4
# failed
# 4
# succeeded
# succeeded
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# failed
# 5
# succeeded
# succeeded
# 6
# failed
# 6
# failed
# 6
# failed
# 6
# failed
# 6
# failed
# 6
# failed
# 6
# failed
# 6
# succeeded
# succeeded
# 7
# failed
# 7
# failed
# 7
# failed
# 7
# failed
# 7
# failed
# 7
# failed
# 7
# failed
# 7
# succeeded
# succeeded
# 8
# failed
# 8
# succeeded
# succeeded
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# failed
# 9
# succeeded
# succeeded
# 10
# failed
# 10
# succeeded
# succeeded
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# failed
# 11
# succeeded
# succeeded
# 12
# failed
# 12
# failed
# 12
# failed
# 12
# failed
# 12
# failed
# 12
# failed
# 12
# failed
# 12
# failed
# 12
# succeeded
# succeeded
# 13
# failed
# 13
# failed
# 13
# failed
# 13
# failed
# 13
# failed
# 13
# succeeded
# succeeded
# 14
# failed
# 14
# succeeded
# succeeded
# 15
# failed
# 15
# failed
# 15
# failed
# 15
# failed
# 15
# failed
# 15
# succeeded
# succeeded
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# failed
# 16
# succeeded
# succeeded
# 17
# failed
# 17
# succeeded
# succeeded
# 18
# failed
# 18
# failed
# 18
# failed
# 18
# succeeded
# succeeded
# 19
# failed
# 19
# failed
# 19
# failed
# 19
# failed
# 19
# failed
# 19
# succeeded
# succeeded
# 20
# succeeded
# succeeded
# 21
# failed
# 21
# failed
# 21
# failed
# 21
# succeeded
# succeeded
# 22
# failed
# 22
# failed
# 22
# failed
# 22
# failed
# 22
# failed
# 22
# failed
# 22
# succeeded
# succeeded
# 23
# succeeded
# succeeded
# 24
# failed
# 24
# failed
# 24
# failed
# 24
# failed
# 24
# succeeded
# succeeded
# 25
# failed
# 25
# failed
# 25
# failed
# 25
# succeeded
# succeeded
# 26
# failed
# 26
# succeeded
# succeeded
# 27
# failed
# 27
# succeeded
# succeeded
# 28
# succeeded
# succeeded
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# failed
# 29
# succeeded
# succeeded
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# failed
# 30
# succeeded
# succeeded
# 31
# failed
# 31
# failed
# 31
# failed
# 31
# failed
# 31
# failed
# 31
# failed
# 31
# failed
# 31
# succeeded
# succeeded
# 32
# failed
# 32
# failed
# 32
# succeeded
# succeeded
# 33
# failed
# 33
# failed
# 33
# succeeded
# succeeded
# 34
# failed
# 34
# failed
# 34
# succeeded
# succeeded
# 35
# succeeded
# succeeded
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# failed
# 36
# succeeded
# succeeded
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# failed
# 37
# succeeded
# succeeded
# 38
# failed
# 38
# failed
# 38
# succeeded
# succeeded
# 39
# failed
# 39
# failed
# 39
# failed
# 39
# failed
# 39
# succeeded
# succeeded
# 40
# failed
# 40
# succeeded
# succeeded
# 41
# failed
# 41
# failed
# 41
# failed
# 41
# failed
# 41
# failed
# 41
# failed
# 41
# failed
# 41
# succeeded
# succeeded
# 42
# succeeded
# succeeded
# 43
# failed
# 43
# failed
# 43
# succeeded
# succeeded
# 44
# failed
# 44
# failed
# 44
# failed
# 44
# succeeded
# succeeded
# 45
# failed
# 45
# failed
# 45
# failed
# 45
# failed
# 45
# failed
# 45
# succeeded
# succeeded
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# failed
# 46
# succeeded
# succeeded
# 47
# failed
# 47
# failed
# 47
# failed
# 47
# failed
# 47
# failed
# 47
# failed
# 47
# failed
# 47
# failed
# 47
# succeeded
# succeeded
# 48
# failed
# 48
# succeeded
# succeeded
# 49
# failed
# 49
# succeeded
# succeeded
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# failed
# 50
# succeeded
# succeeded
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# failed
# 51
# succeeded
# succeeded
# 52
# failed
# 52
# succeeded
# succeeded
# 53
# failed
# 53
# failed
# 53
# succeeded
# succeeded
# 54
# failed
# 54
# failed
# 54
# failed
# 54
# failed
# 54
# failed
# 54
# failed
# 54
# succeeded
# succeeded
# 55
# succeeded
# succeeded
# 56
# failed
# 56
# failed
# 56
# failed
# 56
# failed
# 56
# failed
# 56
# failed
# 56
# failed
# 56
# failed
# 56
# failed
# 56
# succeeded
# succeeded
# 57
# failed
# 57
# failed
# 57
# failed
# 57
# failed
# 57
# failed
# 57
# failed
# 57
# failed
# 57
# succeeded
# succeeded
# 58
# succeeded
# succeeded
# 59
# failed
# 59
# succeeded
# succeeded
# 60
# succeeded
# succeeded
# 61
# failed
# 61
# failed
# 61
# failed
# 61
# failed
# 61
# failed
# 61
# failed
# 61
# failed
# 61
# failed
# 61
# succeeded
# succeeded
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# failed
# 62
# succeeded
# succeeded
# 63
# failed
# 63
# failed
# 63
# succeeded
# succeeded
# 64
# failed
# 64
# failed
# 64
# failed
# 64
# succeeded
# succeeded
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# failed
# 65
# succeeded
# succeeded
# 66
# failed
# 66
# failed
# 66
# failed
# 66
# failed
# 66
# failed
# 66
# failed
# 66
# failed
# 66
# succeeded
# succeeded
# 67
# succeeded
# succeeded
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# failed
# 68
# succeeded
# succeeded
# 69
# succeeded
# succeeded
# 70
# failed
# 70
# failed
# 70
# succeeded
# succeeded
# 71
# failed
# 71
# failed
# 71
# failed
# 71
# failed
# 71
# failed
# 71
# failed
# 71
# failed
# 71
# failed
# 71
# succeeded
# succeeded
# 72
# failed
# 72
# failed
# 72
# failed
# 72
# failed
# 72
# failed
# 72
# failed
# 72
# failed
# 72
# succeeded
# succeeded
# 73
# failed
# 73
# failed
# 73
# failed
# 73
# succeeded
# succeeded
# 74
# failed
# 74
# failed
# 74
# failed
# 74
# failed
# 74
# failed
# 74
# succeeded
# succeeded
# 75
# failed
# 75
# failed
# 75
# succeeded
# succeeded
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# failed
# 76
# succeeded
# succeeded
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# failed
# 77
# succeeded
# succeeded
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# failed
# 78
# succeeded
# succeeded
# 79
# succeeded
# succeeded
# 80
# failed
# 80
# succeeded
# succeeded
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# failed
# 81
# succeeded
# succeeded
# 82
# failed
# 82
# failed
# 82
# failed
# 82
# succeeded
# succeeded
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# failed
# 83
# succeeded
# succeeded
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# failed
# 84
# succeeded
# succeeded
# 85
# failed
# 85
# failed
# 85
# failed
# 85
# failed
# 85
# failed
# 85
# failed
# 85
# failed
# 85
# failed
# 85
# succeeded
# succeeded
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# failed
# 86
# succeeded
# succeeded
# 87
# failed
# 87
# failed
# 87
# failed
# 87
# failed
# 87
# failed
# 87
# failed
# 87
# failed
# 87
# failed
# 87
# succeeded
# succeeded
# 88
# failed
# 88
# failed
# 88
# failed
# 88
# succeeded
# succeeded
# 89
# failed
# 89
# failed
# 89
# failed
# 89
# succeeded
# succeeded
# 90
# failed
# 90
# failed
# 90
# failed
# 90
# failed
# 90
# succeeded
# succeeded
# 91
# succeeded
# succeeded
# 92
# failed
# 92
# failed
# 92
# failed
# 92
# failed
# 92
# failed
# 92
# succeeded
# succeeded
# 93
# failed
# 93
# failed
# 93
# succeeded
# succeeded
# 94
# failed
# 94
# failed
# 94
# failed
# 94
# failed
# 94
# failed
# 94
# failed
# 94
# succeeded
# succeeded
# 95
# failed
# 95
# succeeded
# succeeded
# 96
# failed
# 96
# succeeded
# succeeded
# 97
# failed
# 97
# failed
# 97
# failed
# 97
# failed
# 97
# failed
# 97
# succeeded
# succeeded
# 98
# failed
# 98
# failed
# 98
# failed
# 98
# failed
# 98
# failed
# 98
# failed
# 98
# failed
# 98
# failed
# 98
# succeeded
# succeeded
# 99
# failed
# 99
# failed
# 99
# failed
# 99
# failed
# 99
# failed
# 99
# succeeded
# succeeded
# 100
# failed
# 100
# failed
# 100
# failed
# 100
# failed
# 100
# failed
# 100
# failed
# 100
# failed
# 100
# failed
# 100
# succeeded
# succeeded
# 101
# failed
# 101
# failed
# 101
# failed
# 101
# failed
# 101
# failed
# 101
# failed
# 101
# succeeded
# succeeded
# 102
# failed
# 102
# failed
# 102
# failed
# 102
# failed
# 102
# failed
# 102
# succeeded
# succeeded
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# failed
# 103
# succeeded
# succeeded
# 104
# failed
# 104
# failed
# 104
# failed
# 104
# failed
# 104
# succeeded
# succeeded
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# failed
# 105
# succeeded
# succeeded
# 106
# failed
# 106
# failed
# 106
# failed
# 106
# failed
# 106
# succeeded
# succeeded
# 107
# failed
# 107
# failed
# 107
# failed
# 107
# failed
# 107
# failed
# 107
# failed
# 107
# failed
# 107
# succeeded
# succeeded
# 108
# failed
# 108
# failed
# 108
# failed
# 108
# succeeded
# succeeded
# 109
# failed
# 109
# failed
# 109
# failed
# 109
# failed
# 109
# failed
# 109
# failed
# 109
# failed
# 109
# failed
# 109
# failed
# 109
# succeeded
# succeeded
# 110
# failed
# 110
# failed
# 110
# failed
# 110
# failed
# 110
# failed
# 110
# failed
# 110
# succeeded
# succeeded
# 111
# failed
# 111
# succeeded
# succeeded
# 112
# succeeded
# succeeded
# 113
# failed
# 113
# failed
# 113
# failed
# 113
# succeeded
# succeeded
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# failed
# 114
# succeeded
# succeeded
# 115
# failed
# 115
# failed
# 115
# failed
# 115
# failed
# 115
# failed
# 115
# succeeded
# succeeded
# 116
# succeeded
# succeeded
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# failed
# 117
# succeeded
# succeeded
# 118
# failed
# 118
# failed
# 118
# failed
# 118
# failed
# 118
# failed
# 118
# failed
# 118
# failed
# 118
# failed
# 118
# succeeded
# succeeded
# 119
# failed
# 119
# failed
# 119
# failed
# 119
# failed
# 119
# succeeded
# succeeded
# 120
# failed
# 120
# failed
# 120
# failed
# 120
# failed
# 120
# failed
# 120
# failed
# 120
# failed
# 120
# succeeded
# succeeded
# 121
# failed
# 121
# failed
# 121
# failed
# 121
# failed
# 121
# failed
# 121
# failed
# 121
# failed
# 121
# failed
# 121
# failed
# 121
# succeeded
# succeeded
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# failed
# 122
# succeeded
# succeeded
# 123
# failed
# 123
# failed
# 123
# failed
# 123
# succeeded
# succeeded
# 124
# succeeded
# succeeded
# 125
# failed
# 125
# failed
# 125
# failed
# 125
# failed
# 125
# failed
# 125
# failed
# 125
# failed
# 125
# succeeded
# succeeded
# 126
# succeeded
# succeeded
# 127
# failed
# 127
# failed
# 127
# failed
# 127
# failed
# 127
# succeeded
# succeeded
# 128
# failed
# 128
# failed
# 128
# failed
# 128
# failed
# 128
# failed
# 128
# succeeded
# succeeded
# 129
# failed
# 129
# failed
# 129
# succeeded
# succeeded
# 130
# failed
# 130
# failed
# 130
# failed
# 130
# failed
# 130
# failed
# 130
# failed
# 130
# failed
# 130
# failed
# 130
# succeeded
# succeeded
# 131
# failed
# 131
# failed
# 131
# succeeded
# succeeded
# 132
# failed
# 132
# failed
# 132
# failed
# 132
# failed
# 132
# failed
# 132
# succeeded
# succeeded
# 133
# failed
# 133
# failed
# 133
# succeeded
# succeeded
# 134
# failed
# 134
# succeeded
# succeeded
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# failed
# 135
# succeeded
# succeeded
# 136
# succeeded
# succeeded
# 137
# failed
# 137
# failed
# 137
# failed
# 137
# succeeded
# succeeded
# 138
# failed
# 138
# failed
# 138
# failed
# 138
# failed
# 138
# failed
# 138
# succeeded
# succeeded
# 139
# failed
# 139
# failed
# 139
# failed
# 139
# failed
# 139
# succeeded
# succeeded
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# failed
# 140
# succeeded
# succeeded
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# failed
# 141
# succeeded
# succeeded
# 142
# succeeded
# succeeded
# 143
# succeeded
# succeeded
# 144
# failed
# 144
# failed
# 144
# failed
# 144
# failed
# 144
# failed
# 144
# failed
# 144
# failed
# 144
# succeeded
# succeeded
# 145
# succeeded
# succeeded
# 146
# succeeded
# succeeded
# 147
# failed
# 147
# failed
# 147
# failed
# 147
# failed
# 147
# failed
# 147
# succeeded
# succeeded
# 148
# succeeded
# succeeded
# 149
# failed
# 149
# succeeded
# succeeded
# 150
# succeeded
# succeeded
# 151
# failed
# 151
# failed
# 151
# failed
# 151
# failed
# 151
# failed
# 151
# failed
# 151
# succeeded
# succeeded
# 152
# failed
# 152
# failed
# 152
# succeeded
# succeeded
# 153
# failed
# 153
# failed
# 153
# failed
# 153
# failed
# 153
# succeeded
# succeeded
# 154
# succeeded
# succeeded
# 155
# succeeded
# succeeded
# 156
# failed
# 156
# failed
# 156
# failed
# 156
# failed
# 156
# succeeded
# succeeded
# 157
# failed
# 157
# succeeded
# succeeded
# 158
# failed
# 158
# failed
# 158
# failed
# 158
# failed
# 158
# succeeded
# succeeded
# 159
# failed
# 159
# failed
# 159
# succeeded
# succeeded
# 160
# succeeded
# succeeded
# 161
# succeeded
# succeeded
# 162
# failed
# 162
# succeeded
# succeeded
# 163
# failed
# 163
# succeeded
# succeeded
# 164
# failed
# 164
# failed
# 164
# failed
# 164
# succeeded
# succeeded
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# failed
# 165
# succeeded
# succeeded
# 166
# succeeded
# succeeded
# 167
# failed
# 167
# failed
# 167
# succeeded
# succeeded
# 168
# succeeded
# succeeded
# 169
# failed
# 169
# failed
# 169
# failed
# 169
# failed
# 169
# succeeded
# succeeded
# 170
# failed
# 170
# succeeded
# succeeded
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# failed
# 171
# succeeded
# succeeded
# 172
# failed
# 172
# failed
# 172
# succeeded
# succeeded
# 173
# failed
# 173
# failed
# 173
# failed
# 173
# failed
# 173
# failed
# 173
# failed
# 173
# succeeded
# succeeded
# 174
# failed
# 174
# failed
# 174
# failed
# 174
# succeeded
# succeeded
# 175
# failed
# 175
# failed
# 175
# succeeded
# succeeded
# 176
# succeeded
# succeeded
# 177
# succeeded
# succeeded
# 178
# failed
# 178
# failed
# 178
# succeeded
# succeeded
# 179
# succeeded
# succeeded
# 180
# failed
# 180
# failed
# 180
# failed
# 180
# failed
# 180
# failed
# 180
# failed
# 180
# failed
# 180
# failed
# 180
# failed
# 180
# succeeded
# succeeded
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# failed
# 181
# succeeded
# succeeded
# 182
# failed
# 182
# failed
# 182
# failed
# 182
# succeeded
# succeeded
# 183
# succeeded
# succeeded
# 184
# failed
# 184
# failed
# 184
# failed
# 184
# failed
# 184
# failed
# 184
# failed
# 184
# failed
# 184
# succeeded
# succeeded
# 185
# failed
# 185
# failed
# 185
# failed
# 185
# succeeded
# succeeded
# 186
# failed
# 186
# failed
# 186
# failed
# 186
# failed
# 186
# failed
# 186
# failed
# 186
# failed
# 186
# succeeded
# succeeded
# 187
# succeeded
# succeeded
# 188
# failed
# 188
# succeeded
# succeeded
# 189
# succeeded
# succeeded
# 190
# failed
# 190
# succeeded
# succeeded
# 191
# failed
# 191
# failed
# 191
# failed
# 191
# failed
# 191
# failed
# 191
# failed
# 191
# succeeded
# succeeded
# 192
# failed
# 192
# failed
# 192
# succeeded
# succeeded
# 193
# failed
# 193
# failed
# 193
# failed
# 193
# failed
# 193
# failed
# 193
# failed
# 193
# succeeded
# succeeded
# 194
# failed
# 194
# failed
# 194
# failed
# 194
# failed
# 194
# failed
# 194
# failed
# 194
# succeeded
# succeeded
# 195
# failed
# 195
# failed
# 195
# failed
# 195
# failed
# 195
# failed
# 195
# failed
# 195
# succeeded
# succeeded
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# failed
# 196
# succeeded
# succeeded
# 197
# failed
# 197
# failed
# 197
# failed
# 197
# failed
# 197
# failed
# 197
# succeeded
# succeeded
# 198
# failed
# 198
# failed
# 198
# failed
# 198
# succeeded
# succeeded
# 199
# failed
# 199
# failed
# 199
# succeeded
# succeeded
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# failed
# 200
# succeeded
# succeeded
# 201
# failed
# 201
# failed
# 201
# failed
# 201
# failed
# 201
# failed
# 201
# failed
# 201
# succeeded
# succeeded
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# failed
# 202
# succeeded
# succeeded
# 203
# failed
# 203
# succeeded
# succeeded
# 204
# failed
# 204
# failed
# 204
# failed
# 204
# failed
# 204
# failed
# 204
# failed
# 204
# failed
# 204
# failed
# 204
# failed
# 204
# succeeded
# succeeded
# 205
# failed
# 205
# succeeded
# succeeded
# 206
# succeeded
# succeeded
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# failed
# 207
# succeeded
# succeeded
# 208
# succeeded
# succeeded
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# failed
# 209
# succeeded
# succeeded
# 210
# failed
# 210
# failed
# 210
# failed
# 210
# failed
# 210
# failed
# 210
# failed
# 210
# succeeded
# succeeded
# 211
# failed
# 211
# failed
# 211
# succeeded
# succeeded
# 212
# failed
# 212
# failed
# 212
# failed
# 212
# failed
# 212
# failed
# 212
# failed
# 212
# failed
# 212
# failed
# 212
# failed
# 212
# succeeded
# succeeded
# 213
# failed
# 213
# failed
# 213
# failed
# 213
# failed
# 213
# failed
# 213
# failed
# 213
# failed
# 213
# succeeded
# succeeded
# 214
# failed
# 214
# failed
# 214
# failed
# 214
# succeeded
# succeeded
# 215
# failed
# 215
# succeeded
# succeeded
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# failed
# 216
# succeeded
# succeeded
# 217
# failed
# 217
# failed
# 217
# failed
# 217
# failed
# 217
# succeeded
# succeeded
# 218
# succeeded
# succeeded
# 219
# succeeded
# succeeded
# 220
# failed
# 220
# succeeded
# succeeded
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# failed
# 221
# succeeded
# succeeded
# 222
# failed
# 222
# failed
# 222
# failed
# 222
# failed
# 222
# failed
# 222
# failed
# 222
# failed
# 222
# succeeded
# succeeded
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# failed
# 223
# succeeded
# succeeded
# 224
# failed
# 224
# failed
# 224
# failed
# 224
# failed
# 224
# failed
# 224
# failed
# 224
# failed
# 224
# succeeded
# succeeded
# 225
# failed
# 225
# failed
# 225
# failed
# 225
# failed
# 225
# succeeded
# succeeded
# 226
# failed
# 226
# failed
# 226
# failed
# 226
# succeeded
# succeeded
# 227
# failed
# 227
# succeeded
# succeeded
# 228
# succeeded
# succeeded
# 229
# failed
# 229
# failed
# 229
# failed
# 229
# failed
# 229
# failed
# 229
# succeeded
# succeeded
# 230
# failed
# 230
# failed
# 230
# failed
# 230
# failed
# 230
# failed
# 230
# failed
# 230
# failed
# 230
# failed
# 230
# succeeded
# succeeded
# 231
# failed
# 231
# succeeded
# succeeded
# 232
# failed
# 232
# succeeded
# succeeded
# 233
# failed
# 233
# failed
# 233
# failed
# 233
# failed
# 233
# failed
# 233
# succeeded
# succeeded
# 234
# failed
# 234
# failed
# 234
# failed
# 234
# succeeded
# succeeded
# 235
# failed
# 235
# failed
# 235
# failed
# 235
# failed
# 235
# failed
# 235
# failed
# 235
# failed
# 235
# succeeded
# succeeded
# 236
# succeeded
# succeeded
# 237
# failed
# 237
# failed
# 237
# failed
# 237
# failed
# 237
# succeeded
# succeeded
# 238
# failed
# 238
# succeeded
# succeeded
# 239
# succeeded
# succeeded
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# failed
# 240
# succeeded
# succeeded
# 241
# failed
# 241
# failed
# 241
# failed
# 241
# failed
# 241
# succeeded
# succeeded
# 242
# failed
# 242
# succeeded
# succeeded
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# failed
# 243
# succeeded
# succeeded
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# failed
# 244
# succeeded
# succeeded
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# failed
# 245
# succeeded
# succeeded
# 246
# failed
# 246
# succeeded
# succeeded
# 247
# failed
# 247
# failed
# 247
# failed
# 247
# failed
# 247
# failed
# 247
# succeeded
# succeeded
# 248
# failed
# 248
# failed
# 248
# failed
# 248
# succeeded
# succeeded
# 249
# failed
# 249
# failed
# 249
# failed
# 249
# failed
# 249
# failed
# 249
# succeeded
# succeeded
# 250
# succeeded
# succeeded
# 251
# failed
# 251
# succeeded
# succeeded
# 252
# failed
# 252
# succeeded
# succeeded
# 253
# failed
# 253
# failed
# 253
# failed
# 253
# succeeded
# succeeded
# 254
# failed
# 254
# failed
# 254
# failed
# 254
# failed
# 254
# failed
# 254
# failed
# 254
# succeeded
# succeeded
# 255
# failed
# 255
# failed
# 255
# failed
# 255
# failed
# 255
# failed
# 255
# succeeded
# succeeded
# 256
# failed
# 256
# succeeded
# succeeded
# 257
# failed
# 257
# succeeded
# succeeded
# 258
# failed
# 258
# failed
# 258
# failed
# 258
# failed
# 258
# failed
# 258
# succeeded
# succeeded
# 259
# failed
# 259
# succeeded
# succeeded
# 260
# failed
# 260
# failed
# 260
# failed
# 260
# failed
# 260
# failed
# 260
# failed
# 260
# succeeded
# succeeded
# 261
# failed
# 261
# failed
# 261
# failed
# 261
# failed
# 261
# failed
# 261
# failed
# 261
# failed
# 261
# failed
# 261
# succeeded
# succeeded
# 262
# failed
# 262
# failed
# 262
# failed
# 262
# failed
# 262
# succeeded
# succeeded
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# failed
# 263
# succeeded
# succeeded
# 264
# failed
# 264
# failed
# 264
# failed
# 264
# failed
# 264
# succeeded
# succeeded
# 265
# failed
# 265
# failed
# 265
# failed
# 265
# failed
# 265
# failed
# 265
# failed
# 265
# failed
# 265
# failed
# 265
# succeeded
# succeeded
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# failed
# 266
# succeeded
# succeeded
# 267
# failed
# 267
# failed
# 267
# failed
# 267
# failed
# 267
# failed
# 267
# succeeded
# succeeded
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# failed
# 268
# succeeded
# succeeded
# 269
# failed
# 269
# succeeded
# succeeded
# 270
# failed
# 270
# failed
# 270
# succeeded
# succeeded
# 271
# failed
# 271
# failed
# 271
# failed
# 271
# failed
# 271
# failed
# 271
# failed
# 271
# failed
# 271
# failed
# 271
# failed
# 271
# succeeded
# succeeded
# 272
# succeeded
# succeeded
# 273
# failed
# 273
# failed
# 273
# succeeded
# succeeded
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# failed
# 274
# succeeded
# succeeded
# 275
# succeeded
# succeeded
# 276
# failed
# 276
# failed
# 276
# failed
# 276
# failed
# 276
# failed
# 276
# succeeded
# succeeded
# 277
# succeeded
# succeeded
# 278
# failed
# 278
# failed
# 278
# failed
# 278
# failed
# 278
# failed
# 278
# succeeded
# succeeded
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# failed
# 279
# succeeded
# succeeded
# 280
# failed
# 280
# failed
# 280
# succeeded
# succeeded
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# failed
# 281
# succeeded
# succeeded
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# failed
# 282
# succeeded
# succeeded
# 283
# failed
# 283
# failed
# 283
# failed
# 283
# failed
# 283
# failed
# 283
# failed
# 283
# succeeded
# succeeded
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# failed
# 284
# succeeded
# succeeded
# 285
# failed
# 285
# failed
# 285
# failed
# 285
# failed
# 285
# failed
# 285
# succeeded
# succeeded
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# failed
# 286
# succeeded
# succeeded
# 287
# succeeded
# succeeded
# 288
# failed
# 288
# succeeded
# succeeded
# 289
# failed
# 289
# failed
# 289
# failed
# 289
# failed
# 289
# succeeded
# succeeded
# 290
# failed
# 290
# failed
# 290
# succeeded
# succeeded
# 291
# failed
# 291
# failed
# 291
# failed
# 291
# succeeded
# succeeded
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# failed
# 292
# succeeded
# succeeded
# 293
# failed
# 293
# succeeded
# succeeded
# 294
# failed
# 294
# failed
# 294
# failed
# 294
# succeeded
# succeeded
# 295
# failed
# 295
# failed
# 295
# failed
# 295
# failed
# 295
# succeeded
# succeeded
# 296
# failed
# 296
# failed
# 296
# failed
# 296
# failed
# 296
# failed
# 296
# succeeded
# succeeded
# 297
# failed
# 297
# failed
# 297
# failed
# 297
# failed
# 297
# succeeded
# succeeded
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# failed
# 298
# succeeded
# succeeded
# 299
# failed
# 299
# failed
# 299
# failed
# 299
# failed
# 299
# failed
# 299
# failed
# 299
# succeeded
# succeeded
# 300
# failed
# 300
# failed
# 300
# failed
# 300
# failed
# 300
# succeeded
# succeeded
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# failed
# 301
# succeeded
# succeeded
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# failed
# 302
# succeeded
# succeeded
# 303
# failed
# 303
# failed
# 303
# failed
# 303
# failed
# 303
# failed
# 303
# failed
# 303
# failed
# 303
# succeeded
# succeeded
# 304
# failed
# 304
# failed
# 304
# succeeded
# succeeded
# 305
# succeeded
# succeeded
# 306
# succeeded
# succeeded
# 307
# failed
# 307
# succeeded
# succeeded
# 308
# succeeded
# succeeded
# 309
# succeeded
# succeeded
# 310
# succeeded
# succeeded
# 311
# failed
# 311
# failed
# 311
# failed
# 311
# succeeded
# succeeded
# 312
# failed
# 312
# failed
# 312
# failed
# 312
# failed
# 312
# failed
# 312
# failed
# 312
# succeeded
# succeeded
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# failed
# 313
# succeeded
# succeeded
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# failed
# 314
# succeeded
# succeeded
# 315
# failed
# 315
# failed
# 315
# failed
# 315
# failed
# 315
# failed
# 315
# failed
# 315
# succeeded
# succeeded
# 316
# failed
# 316
# failed
# 316
# failed
# 316
# failed
# 316
# failed
# 316
# failed
# 316
# failed
# 316
# failed
# 316
# succeeded
# succeeded
# 317
# succeeded
# succeeded
# 318
# failed
# 318
# failed
# 318
# failed
# 318
# failed
# 318
# failed
# 318
# failed
# 318
# failed
# 318
# failed
# 318
# succeeded
# succeeded
# 319
# failed
# 319
# failed
# 319
# succeeded
# succeeded
# 320
# failed
# 320
# succeeded
# succeeded
# 321
# failed
# 321
# failed
# 321
# succeeded
# succeeded
# 322
# failed
# 322
# succeeded
# succeeded
# 323
# failed
# 323
# failed
# 323
# failed
# 323
# failed
# 323
# failed
# 323
# failed
# 323
# failed
# 323
# failed
# 323
# failed
# 323
# succeeded
# succeeded
# 324
# succeeded
# succeeded
# 325
# failed
# 325
# failed
# 325
# succeeded
# succeeded
# 326
# failed
# 326
# succeeded
# succeeded
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# failed
# 327
# succeeded
# succeeded
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# failed
# 328
# succeeded
# succeeded
# 329
# failed
# 329
# failed
# 329
# failed
# 329
# failed
# 329
# succeeded
# succeeded
# 330
# failed
# 330
# failed
# 330
# succeeded
# succeeded
# 331
# failed
# 331
# failed
# 331
# failed
# 331
# failed
# 331
# succeeded
# succeeded
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# failed
# 332
# succeeded
# succeeded
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# failed
# 333
# succeeded
# succeeded
# 334
# failed
# 334
# failed
# 334
# failed
# 334
# failed
# 334
# failed
# 334
# failed
# 334
# succeeded
# succeeded
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# failed
# 335
# succeeded
# succeeded
# 336
# failed
# 336
# failed
# 336
# failed
# 336
# failed
# 336
# succeeded
# succeeded
# 337
# failed
# 337
# failed
# 337
# failed
# 337
# succeeded
# succeeded
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338
# failed
# 338

# %%
level_index = solution_dict[list(solution_dict.keys())[0]][model_type]["level"].index

# %%
if V2G: mode = "V2G" 
else: mode = "G2V"
    
with open(f'no_pub_level{short_or_long}_solution_dict_{mode}_{soc_min}.pickle', 'wb') as handle:
    pickle.dump(solution_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

#with open('medium_solution_dict_G2V_0.pickle', 'rb') as handle:
 #   solution_dict = pickle.load(handle)

# %% [markdown]
# ## Processing EES-profiles: Aggregation

# %%
uncontrolled_level_accurate, uncontrolled_charge_df, early, late = pd.DataFrame(), pd.DataFrame(), pd.DataFrame(),pd.DataFrame()
df_con, df_pow, df_neg_pow, df_pro =  pd.DataFrame(), pd.DataFrame(),pd.DataFrame(),pd.DataFrame()

count = 0
keys = list(solution_dict.keys())
for c in consumption_raw.columns.unique():
    try: 
        car_list = consumption_raw[c].columns
    except AttributeError as a:
        car_list = [c]
        
    for i, car in enumerate(car_list):
        if car+str(i) in keys:
            try: 
                
                early = pd.concat([
                    early, solution_dict[car+str(i)]["m_early"]["level"]
                ], axis=1).sum(1)
                late = pd.concat([
                   late, solution_dict[car+str(i)]["m_late"]["level"]
                ], axis=1).sum(1)
                uncontrolled_charge_df = pd.concat([
                    uncontrolled_charge_df, solution_dict[car+str(i)]["m_early"]["charge"]
                ], axis=1)
                

                
            

                if type(consumption_raw[car]) == pd.core.series.Series: 
                    df_con[car] = consumption_raw[car]
                    df_pow[car] = power_raw[car]
                    df_neg_pow[car] = neg_power_magnitude_raw[car]
                    df_pro[car] = car_properties_raw[car]
                else: 
                    df_con[car+str(i)] = consumption_raw[car].iloc[:,i]
                    df_pow[car+str(i)] = power_raw[car].iloc[:,i]
                    #df_neg_pow[car+str(i)] = neg_power_magnitude_raw[car].iloc[:,i]
                    df_pro[car+str(i)] = car_properties_raw[car].iloc[:,i]
                print(count)  
                count +=1
            except KeyError: 
                print(car+str(i))
                pass
            
level_0_agg = sum(df_pro.loc["soc_init"]*df_pro.loc["battery_capacity"])
level_T_agg = sum(df_pro.loc["soc_end"]*df_pro.loc["battery_capacity"])   

uncontrolled_level_accurate = early
uncontrolled_level_accurate.iloc[0] = level_0_agg ##
uncontrolled_level_accurate.name = "uncontrolled_level"

uncontrolled_charge_accurate = uncontrolled_charge_df.sum(1)

uncontrolled_charge_accurate.name = "uncontrolled_charge"        
ees_constraints_aggergated=late-early
# Out:
# Tesla/Model_3_Long_Range_AWD/20190
# Tesla/Model_3_Long_Range_AWD/20191
# 0
# Tesla/Model_3_Long_Range_AWD/20193
# Tesla/Model_3_Long_Range_AWD/20194
# 1
# Tesla/Model_3_Long_Range_AWD/20196
# 2
# 3
# Tesla/Model_3_Long_Range_AWD/20199
# 4
# Tesla/Model_3_Long_Range_AWD/201911
# Tesla/Model_3_Long_Range_AWD/201912
# 5
# 6
# 7
# Tesla/Model_3_Long_Range_AWD/201916
# Tesla/Model_3_Long_Range_AWD/201917
# 4217
# 4218
# Volkswagen/e-Golf_SE/2019800
# Volkswagen/e-Golf_SE/2019801
# Volkswagen/e-Golf_SE/2019802
# Volkswagen/e-Golf_SE/2019803
# 4219
# 4220
# Volkswagen/e-Golf_SE/2019806
# Volkswagen/e-Golf_SE/2019807
# 4221
# 4222
# 4223
# Volkswagen/e-Golf_SE/2019811
# 4224
# Volkswagen/e-Golf_SE/2019813
# 4225
# 4226
# 4227
# Volkswagen/e-Golf_SE/2019817
# 4228
# Volkswagen/e-Golf_SE/2019819
# Volkswagen/e-Golf_SE/2019820
# 4229
# Volkswagen/e-Golf_SE/2019822
# Volkswagen/e-Golf_SE/2019823
# Volkswagen/e-Golf_SE/2019824
# 4230
# Volkswagen/e-Golf_SE/2019826
# Volkswagen/e-Golf_SE/2019827
# Volkswagen/e-Golf_SE/2019828
# 4231
# 4232
# Volkswagen/e-Golf_SE/2019831
# Volkswagen/e-Golf_SE/2019832
# 4233
# Volkswagen/e-Golf_SE/2019834
# 4234
# 4235
# 4236
# Volkswagen/e-Golf_SE/2019838
# Volkswagen/e-Golf_SE/2019839
# 4237
# Volkswagen/e-Golf_SE/2019841
# 4238
# Volkswagen/e-Golf_SE/2019843
# Volkswagen/e-Golf_SE/2019844
# 4239
# 4240
# 4241
# Volkswagen/e-Golf_SE/2019848
# Volkswagen/e-Golf_SE/2019849
# Volkswagen/e-Golf_SE/2019850
# Volkswagen/e-Golf_SE/2019851
# Volkswagen/e-Golf_SE/2019852
# Volkswagen/e-Golf_SE/2019853
# 4242
# Volkswagen/e-Golf_SE/2019855
# Volkswagen/e-Golf_SE/2019856
# 4243
# Volkswagen/e-Golf_SE/2019858
# 4244
# Volkswagen/e-Golf_SE/2019860
# Volkswagen/e-Golf_SE/2019861
# 4245
# Volkswagen/e-Golf_SE/2019863
# Volkswagen/e-Golf_SE/2019864
# Volkswagen/e-Golf_SE/2019865
# Volkswagen/e-Golf_SE/2019866
# Volkswagen/e-Golf_SE/2019867
# 4246
# 4247
# 4248
# 4249
# Volkswagen/e-Golf_SE/2019872
# 4250
# Volkswagen/e-Golf_SE/2019874
# Volkswagen/e-Golf_SE/2019875
# 4251
# 4252

# %%
#df_con.to_pickle("results/df_con_no_pub_level")
#df_pow.to_pickle("results/df_pow_no_pub_level")
#df_neg_pow.to_pickle("results/df_neg_pow_no_pub_level")
#df_pro.to_pickle("results/df_pro_no_pub_level")
#uncontrolled_charge_df.to_pickle("results/uncontrolled_no_pub_level")
#early.to_pickle("results/early_no_pub_level")
#late.to_pickle("results/late_no_pub_level")

df_con = pd.read_pickle("results/df_con_pub")
df_pow = pd.read_pickle("results/df_pow_pub")
df_neg_pow = pd.read_pickle("results/df_neg_pow_pub")
df_pro = pd.read_pickle("results/df_pro_pub")
uncontrolled_charge_df = pd.read_pickle("results/uncontrolled_pub")
early = pd.read_pickle("results/early_pub")
late = pd.read_pickle("results/late_pub")
index, profiles = df_con.index , df_con.shape[1]
level_index  = index.insert(0, index[0]-pd.Timedelta(index.freq))
level_index = index.insert(0, index[0]-pd.Timedelta(index.freq))

# %%
def con(df):
    return pd.concat([df, df], axis=1).iloc[:,:12001]

# %%
df_con = con(df_con)
df_pow = con(df_pow)
df_neg_pow = con(df_neg_pow)
df_pro = con(df_pro)
uncontrolled_charge_df = con(uncontrolled_charge_df)

# %%
df_con, df_pow, df_neg_pow, early, late,  uncontrolled_charge_df= df_con.resample("1h").mean(), df_pow.resample("1h").mean(), df_neg_pow.resample("1h").mean(), early.resample("1h").mean(), late.resample("1h").mean(), uncontrolled_charge_df.resample("1h").mean()
index, profiles = df_con.index , df_con.shape[1]
level_index  = index.insert(0, index[0]-pd.Timedelta(index.freq))

# %%
models = df_pro.columns.str[:10].unique()
m_l = []
for element in models:
    m_l.append(element.split("/")[0])
shares = pd.DataFrame(index=m_l, columns=["shares"])
for m in models:
    shares.loc[m.split("/")[0]] = df_pro.columns.str.contains(m).sum()
n = shares.sum()
shares = shares/n*100

# %%
df_pro.loc["battery_capacity"][5500:]

# %%
level_0_agg = sum(df_pro.loc["soc_init"]*df_pro.loc["battery_capacity"])
level_T_agg = sum(df_pro.loc["soc_end"]*df_pro.loc["battery_capacity"])  

uncontrolled_level_accurate = early
uncontrolled_level_accurate.iloc[0] = level_0_agg ##
uncontrolled_level_accurate.name = "uncontrolled_level"

ees_constraints_aggergated = late-early
uncontrolled_charge_accurate = uncontrolled_charge_df.sum(1)

# %%
fleet_size =  df_con.shape[1]             #sampled.shape[0]#

scale = 15/fleet_size #sampled fleet in kW --> 15 mio EVs in GW
scale_down = 1/fleet_size#sampled fleet in kW --> per EV in kW/EV

# %%
overall_peak = early.max()
overall_consumption_avg = early.mean()

tmp_peak, tmp_cons = pd.DataFrame(),  pd.DataFrame()

count = 0
while count < 12:
    print(count)
    increasing_df = pd.DataFrame(index=range(0, fleet_size), columns=["peak_load", "avg_consumption"])
    ordered_df = uncontrolled_charge_df.sample(frac=1, axis=1)
    for n, i in enumerate(ordered_df.columns):
        
        df = ordered_df.iloc[:, :n]
        sub_peak = df.sum(1).max()
        sub_consumption = df.sum(1).mean()
        scaled_peak = sub_peak * fleet_size / (n+1)
        scaled_consumption = sub_consumption * fleet_size / (n+1)
        increasing_df.iloc[n] = [scaled_peak, scaled_consumption]
    
    tmp_peak[count], tmp_cons[count] = increasing_df["peak_load"], increasing_df["avg_consumption"]
    count += 1

tmp_peak.to_pickle("results/tmp/peak_1")
tmp_cons.to_pickle("results/tmp/cons_1")

# %%
t = np.unique(uncontrolled_charge_df[uncontrolled_charge_df>0])

# %%
df = pd.DataFrame(t)
df_ = df.copy()

# %%
df["home"] = df_[df_<=3.33]
df["public"] =  df_[df_>3.33]
df=df[["home", "public"]]

# %%
s = df.sum()
s[0]/s.sum()

# %%
#sampled = pd.concat([
#    pd.concat([tmp_peak.std(1), tmp_peak.mean(1)],axis = 1, keys = ["std_deviation", "mean"]), 
#    pd.concat([tmp_cons.std(1), tmp_cons.mean(1)],axis = 1, keys = ["std_deviation", "mean"])
#    ], axis = 1, keys = ["peak", "consumption"]).iloc[10:]

#sampled.to_pickle("results/sampled_1")


#p_list=[pd.read_pickle(f"results/{p}") for p in ["sampled", "sampled_1", "sampled_3"]]
#df = pd.concat(p_list, axis=1)
#columns = pd.MultiIndex.from_tuples([
#    ("peak", "mean"), ("peak", "std_deviation"), ("consumption", "mean"), ("consumption","std_deviation")
#])
#sampled = pd.DataFrame(columns=columns, index=df.index)
#sampled.loc[:,("peak", "std_deviation")], sampled.loc[:,("peak","mean")]  = df["peak"]["std_deviation"].max(1), df["peak"]["mean"].mean(1)
#sampled.loc[:,("consumption", "std_deviation")], sampled.loc[:,("consumption", "mean")]  = df["consumption"]["std_deviation"].max(1), df["consumption"]["mean"].mean(1)

# %%
#!pip install pickle5

# %%
from os import listdir
from os.path import isfile, join
files = [f for f in listdir("results/tmp") if isfile(join("results/tmp", f))]
p_files, c_files  = [f for f in files if "peak" in f], [f for f in files if "cons" in f]
p_list = [pd.read_pickle(f"results/tmp/{f}") for f in p_files]
c_list = [pd.read_pickle(f"results/tmp/{f}") for f in c_files]

tmp_peak, tmp_cons = pd.concat(p_list, axis=1), pd.concat(c_list, axis=1)

sampled = pd.concat(
    [        pd.concat(
        [tmp_peak.std(1), tmp_peak.mean(1)],
        axis = 1, keys = ["std_deviation", "mean"]
        ), pd.concat(
        [tmp_cons.std(1), tmp_cons.mean(1)],
        axis = 1, keys = ["std_deviation", "mean"]
        )
    ], axis = 1, keys = ["peak", "consumption"]).iloc[10:].loc[:12000]

# %%
iterations = tmp_peak.shape[1]
iterations
# Out:
# 51

# %%
for i in range(0,10):
    df = uncontrolled_charge_df.sample(frac=1, axis=1).iloc[:,1]
    print(df.max())
# Out:
# 19.3471052631579
# 16.3815789473684
# 12.8947368421053
# 16.4157894736842
# 19.8
# 15.0
# 15.1315789473684
# 17.4328947368421
# 15.2631578947368
# 19.8

# %%
def area_plot(df, peak_or_consumption=True):
    
    df_fleet=df*scale  #15mio EVs in GW 
    df_single = df*scale_down
    
    fig, ax = plt.subplots(figsize=(8, 3.5))
   
    ax.fill_between(
        df_single.index, df_single["mean"]+df_single["std_deviation"], df_single["mean"]-df_single["std_deviation"], alpha=0.5, label="standard deviation"
    ) 
    
    p = df_single["mean"].plot() 
    
    ax2=p.twinx()
    ax2.spines['right'].set_position(('axes',  1))
    
    ax.set_xlabel("Sampling size")
    ax.set_ylabel("Peak load [kW/EV]") 
    ax2.set_ylabel("Peak load [GW]") 
    ax.set_xlim(0)
    
    ax.grid('on', which='minor' , alpha=0.3)
    ax.grid('on', which='major' )

    for i in [0, 1]:
        if i == 0: 
            max_val = round(df_single["mean"].iloc[100], 1)
            min_val = round(df_single["mean"].iloc[-1]*0.9, 1)
            step_size = round((max_val-min_val)/5, 1)
            
            ax.set_ylim(min_val, max_val+step_size/5)
            ax.set_yticks(np.arange(min_val,max_val+step_size, step_size))
        else:
            max_val = round(df_fleet["mean"].iloc[100], 0)
            min_val = round(df_fleet["mean"].iloc[-1]*0.9, 0)
            step_size = round((max_val-min_val)/5, 0)
            
            ax2.set_ylim(min_val, max_val+step_size/5)
            ax2.set_yticks(np.arange(min_val,max_val+step_size, step_size))
    ax.legend()
    plt.show()
    fig.savefig("ADMD.png")

# %%
area_plot(sampled["peak"])
#plt.savefig("ADMD.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/ipykernel_77834/1891484940.py in <module>
# ----> 1 area_plot(sampled["peak"])
#       2 #plt.savefig("ADMD.jpg")
#
# /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/ipykernel_77834/600172011.py in area_plot(df, peak_or_consumption)
#       1 def area_plot(df, peak_or_consumption=True):
#       2
# ----> 3     df_fleet=df*scale  #15mio EVs in GW
#       4     df_single = df*scale_down
#       5
#
# NameError: name 'scale' is not defined

# %%
my = (sampled["peak"]["mean"].iloc[-1]*scale_down)
d = (1.53-my)/my
my*(1+d)

# %%
round(
    (df_con.resample("h").mean()).resample("D").sum().mean(1).mean()*365/0.2
)

# %%
uncontrolled_charge_accurate

# %%
week_list = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
def groupby_weekday(df):
    return df.groupby(df.index.day_name()).mean().reindex(week_list) 

df = uncontrolled_charge_df#df_con
bars = df[(df.index.month==1)&(df.index.day<8)].resample("h").mean().resample("D").sum().mean(1)

groupby_weekday(bars).plot.bar(ylabel = "kWh/day/EV")
# Out:
# <AxesSubplot:ylabel='kWh/day/EV'>

# %%
df = sampled["peak"]["mean"]*scale
df.loc[100]-df.loc[10000]
(df.loc[100]-df.loc[10000])/df.loc[10000]

# %%
def area_plot(df, peak_or_consumption=True):
    df_ev = df * scale_down
    df = df*scale
    
    plt.fill_between(
        df.index, df["mean"]+df["std_deviation"], df["mean"]-df["std_deviation"], alpha=0.5, label="standard deviation"
    ) 
    plt.plot(df.index, df["mean"], label="mean")
    
    ax2 = plt.twinx()
    ax2.spines['right'].set_position(('axes',  1))

    #ax2 = df_ev["mean"].plot(alpha=0, ylabel="%")

    
    plt.xlabel("sampling size")
    plt.ylabel("GW")
    plt.ylim(df["mean"].iloc[-1]*0.9, df["mean"].iloc[200])
    plt.title(
        ("peak" if peak_or_consumption else "average") + " load " + ("for 15 mio EVs & per average EV")
    )
    plt.legend()

# %%
n_l = [100, 200, 500, 1000]
for n in n_l:
    df = sampled["peak"]["mean"]
    df_diff_rel = df.diff(-n)/df*100
    ax = df_diff_rel.plot(ylim=(-0.2,1), xlabel= "Sample size", ylabel="Peak load variation [%]", xlim=(0), label=f'∆profiles: {n}')
    ax.grid()
plt.axhline(color="black", linewidth=0.5)
plt.legend()    
plt.savefig("ADMD_change.png")

# %%
reduced = uncontrolled_charge_df
n_max = uncontrolled_charge_df.shape[1]
rmse = {}

for sample_size in range(10, n_max): 
    Y_true = reduced.max(1)
    Y_pred = reduced.iloc[:,:sample_size].max(1)
    rmse[f'{sample_size}'] = mean_squared_error(Y_true,Y_pred, squared=False) 
    
plt.scatter(range(10, n_max), rmse.values())
plt.xlabel("sample_size")
plt.ylabel("RMSE")
plt.ylim(0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/ipykernel_77834/1333897752.py in <module>
#       6     Y_true = reduced.max(1)
#       7     Y_pred = reduced.iloc[:,:sample_size].max(1)
# ----> 8     rmse[f'{sample_size}'] = mean_squared_error(Y_true,Y_pred, squared=False)
#       9
#      10 plt.scatter(range(10, n_max), rmse.values())
#
# NameError: name 'mean_squared_error' is not defined

# %%
df = uncontrolled_charge_df
condition = ((df.index.month==2 )&(df.index.day>2)&(df.index.day<10))
ts_1 = df[condition].iloc[:, :10000].mean(1)
ts_2 = df[condition].iloc[:, :1000].mean(1)
ts_3 = df[condition].iloc[:, 100:200].mean(1)

df_all = pd.concat([ts_1, ts_2, ts_3], axis=1, keys=["10000 profiles", "1000 profiles", "100 profiles"])


fig, ax = plt.subplots(figsize=(8, 3.5))
ax.plot(df_all.index, df_all)
ax.xaxis.set_major_locator(mdates.DayLocator(interval = 1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))

ax.set_ylabel("Uncontrolled charging [kWh/EV]")
ax.grid('on', which='minor', axis='x', alpha=0.3)
ax.grid('on', which='major' )
#ax.set_xlabel("First Week of February, 2020")
ax.set_xlim(df_all.index[0],df_all.index[-1])
ax.set_ylim(0)
ax.legend(list(df_all.columns))

plt.savefig("uncontrolled.png")

# %%
ees_constraints_aggergated
# Out:
# 2019-12-31 23:30:00   -494329.760000
# 2020-01-01 00:00:00         0.000000
# 2020-01-01 00:30:00         0.000000
# 2020-01-01 01:00:00         0.000000
# 2020-01-01 01:30:00        -9.640789
#                            ...
# 2020-02-14 21:30:00    -14578.919301
# 2020-02-14 22:00:00    -13718.949967
# 2020-02-14 22:30:00    -11654.271433
# 2020-02-14 23:00:00     -7641.781886
# 2020-02-14 23:30:00         0.000000
# Length: 2161, dtype: float64

# %%
#ees_constraints_aggergated = ees_constraints_aggergated.iloc[:time_steps+1, :profiles].sum(1)
level_index = ees_constraints_aggergated.index
aggregated_max_battery = df_pro.loc["battery_capacity"][ :profiles].sum()
ees_constraints_aggergated.iloc[0] = 0

# %%
df = pd.concat([
    -ees_constraints_aggergated, pd.Series(aggregated_max_battery,level_index)
], axis = 1, keys = ["ees", "aggregated_batteries"]).resample("2h").mean()*scale
t = df.index
df_2 = pd.Series(100, t)

ax = df.plot(ylabel="GWh", label = 'level_values')

ax.legend(bbox_to_anchor=(1.05,0.2))

ax2 = ax.twinx()
ax2.spines['right'].set_position(('axes',  1))

ax2 = df_2.plot(alpha=0, ylabel="%")

ax.set_ylim(0), ax2.set_ylim(0)

n = round(df["ees"].max())
ax.axhline(n, color="black", alpha = 1, linewidth=0.8)
ax.text(y=n+20,x=t[-300], s=f"< {n} GWh,  {round(n/df.max().max(), 2)*100}%")

ax.grid('on', which='minor', axis='x' , alpha = 0.3)
ax.grid('on', which='major' )

max_val = 10 - int(df["aggregated_batteries"].max()) % 10 + int(df["aggregated_batteries"].max())

for i, s in enumerate([df, df_2]):
    if i == 0: 
        step_size = (max_val)/5 
        ax.set_ylim(0, max_val+step_size/5)
        ax.set_yticks(np.arange(0,max_val+1, step_size))
    else:
        step_size = 100/5
        ax2.set_ylim(0, 100 +step_size/5)
        ax2.set_yticks(np.arange(0,101, step_size))

#plt.savefig(os.path.join(pics, 'level_comparison_size_ts.png'), bbox_inches = "tight")

# %%
consumption_aggregated =  pd.concat([
    pd.Series(0, index=[index[0]-pd.Timedelta(index.freq)]), df_con.loc[level_index[1:]].sum(1)
              ], axis = 0)
consumption_aggregated.name = "consumption"

power_aggregated = pd.concat([
    pd.Series(0, index=[index[0]-pd.Timedelta(index.freq)]), df_pow.loc[level_index[1:]].sum(1)
              ], axis = 0)

neg_power_aggregated = pd.concat([
    pd.Series(0, index=[index[0]-pd.Timedelta(index.freq)]), df_neg_pow.loc[level_index[1:]].sum(1)
              ], axis = 0)

# %%
#aggregation
naive_constraints_aggergated = pd.Series(data=sum(
    df_pro.loc["battery_capacity"][ :profiles]), index=level_index) #all battery capicities

# %%
condition_1 = ((uncontrolled_level_accurate.index.month ==2) & (uncontrolled_level_accurate.index.day >2) & (uncontrolled_level_accurate.index.day <=9) )
condition_2 = ((uncontrolled_charge_accurate.index.month ==2) & (uncontrolled_charge_accurate.index.day >2)&(uncontrolled_charge_accurate.index.day <=9) )

df, df_2, df_3 = uncontrolled_level_accurate[condition_1], uncontrolled_charge_accurate[condition_2], consumption_aggregated[condition_1]
df, df_2, df_3 = (df*scale_down).resample("4h").mean(), (df_2*scale_down).resample("4h").mean(), (df_3*scale_down).resample("4h").mean()


    



fig, ax = plt.subplots(figsize=(8, 3.5))

ax = df.plot(label = 'level', ylabel="kWh/EV", xticks=[])

ax2 = ax.twinx()
ax2.spines['right'].set_position(('axes',  1))
ax2 = df_2.plot(label = "charge", color="r", ylabel="kW/EV")
ax2 = df_3.plot( label = "consumption", color="y")


lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2,  loc='best', bbox_to_anchor=(1.4, 1.05))

ax.set_ylim(0), ax2.set_ylim(0)
ax.grid('on', which='minor')
ax.grid('on', which='major' )


max_val = int(df.max())
max_val_2 = round(df_2.max(),0)

for i, s in enumerate([df, df_2]):
    if i == 0: 
        step_size = (max_val)/5 
        ax.set_ylim(0, max_val+step_size/5)
        ax.set_yticks(np.arange(0,max_val+1, step_size))
    else:
        step_size = max_val_2/5
        ax2.set_ylim(0, max_val_2 + step_size/5)
        ax2.set_yticks(np.arange(0,max_val_2+step_size/5, step_size))

#plt.tick_params(left = False, right = False , labelleft = False ,
#                labelbottom = False, bottom = False)

#ax.set_xticks([],[])
#ax2.set_xticks([],[])
#ax.xaxis.set_major_locator(mdates.DayLocator(interval=24))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))
#ax2.xaxis.set_major_locator(mdates.DayLocator(interval=24))
#ax2.xaxis.set_major_formatter(mdates.DateFormatter('%a'))

plt.savefig('uncontrolled_level_1.png', bbox_inches = "tight")

# %%
uncontrolled_charge_accurate.max()*scale

# %% [markdown]
# ## Aggregated Optimization

# %%
#!pip install pickle5
import pickle5 as pickle
with open("prices_2020", "rb") as fh:
    data = pickle.load(fh)

# %%
price_mode = "real_price"
prices = data
 
prices.index =  prices.index.map(
    lambda x: pd.to_datetime(x.replace(tzinfo=None))
)
prices = prices[prices.index.drop_duplicates(keep=False)]
prices = prices.reindex(consumption_aggregated.index, method = "ffill") 
prices = prices / (10**3) # €/MWh --> €/kWh

ax = (prices*1000).plot(ylabel="el. price [€/MWh]")

ax.grid('on', which='minor', axis='x' )
ax.grid('on', which='major')

#plt.savefig(os.path.join(pics, 'prices.png'), bbox_inches = "tight")

# %%
#prices = pd.Series(0, prices.index)
#prices[df_con.sum(1).nlargest(1).index] = 1
#price_mode = "artificial_price"

# %%
ax = fig.add_subplot(111)

ax = prices.resample("4h").mean().plot(ylabel="€/kWh", color="b", ylim=(0), label="prices")

ax2 = ax.twinx()
ax2.spines['right'].set_position(('axes',  1))

ax2= df_con.sum(1).resample("4h").mean().plot(label = "highest consumption",  ylim=(0), color="r", ylabel="kWh")

##.loc[level_index.day == 3].

lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2,  loc='best', bbox_to_anchor=(1.55, 1.05))

ax.set_ylim(0), ax2.set_ylim(0)

# %% [markdown]
# Assumptions:
#
# - same price for (DIS)CHARGE
# - 𝑓𝑙𝑒𝑥𝑖𝑏𝑖𝑙𝑖𝑡𝑦 𝑟𝑒𝑣𝑒𝑛𝑢𝑒𝑠 = sum(ees_charging_costs)
# - controlled costs = uncontrolled_costs - 𝑙𝑒𝑥𝑖𝑏𝑖𝑙𝑖𝑡𝑦 𝑟𝑒𝑣𝑒𝑛𝑢𝑒𝑠

# %%
agg_solutions = {}

for model_type in ["naive", "ees"]: 

    #Initialize model
    m_agg = pyo.ConcreteModel()

    #initialize sets
    m_agg.t = pyo.Set(initialize = ees_constraints_aggergated.index, ordered = True)

    m_agg.consumption_aggregated = pyo.Param(m_agg.t, initialize=consumption_aggregated.to_dict())
    m_agg.power = pyo.Param(m_agg.t, initialize=power_aggregated.to_dict()) 
    m_agg.neg_power = pyo.Param(m_agg.t, initialize=neg_power_aggregated.to_dict()) 

    m_agg.LEVEL = pyo.Var(m_agg.t, within = pyo.Reals)
    m_agg.CHARGE = pyo.Var(m_agg.t, within = pyo.NonNegativeReals)
    m_agg.DISCHARGE_PHYS = pyo.Var(m_agg.t, within = pyo.NonNegativeReals)
    m_agg.DISCHARGE_WAIT = pyo.Var(m_agg.t, within = pyo.NonNegativeReals)

    if model_type == "ees":
        m_agg.ees_min = pyo.Param(m_agg.t, initialize=ees_constraints_aggergated.to_dict()) 
        m_agg.uncontrolled_charge = pyo.Param(m_agg.t, initialize=uncontrolled_charge_accurate.to_dict()) 
        
        #recursive level
        def recursive_level(m_agg, t):
            if t == level_index[0]:
                return m_agg.LEVEL[t] == (m_agg.CHARGE[t] - m_agg.DISCHARGE_WAIT[t] - m_agg.DISCHARGE_PHYS[t])*step_duration   
            else:
                return m_agg.LEVEL[t] == m_agg.LEVEL[pd.Timestamp(t) - 
                                                 pd.Timedelta(pd.infer_freq(index))] + (
                    m_agg.CHARGE[t] - m_agg.DISCHARGE_WAIT[t] - m_agg.DISCHARGE_PHYS[t]) * step_duration   
            
    else:
        def final_level(m_agg, t):
            if t == index[-1]:
                return m_agg.LEVEL[t] == level_T_agg
            else: 
                return pyo.Constraint.Skip
        m_agg.Final_level = pyo.Constraint(m_agg.t, rule=final_level)
        
        def recursive_level(m_agg, t):
            if t == level_index[0]: 
                return m_agg.LEVEL[t] == level_0_agg + (m_agg.CHARGE[t]- m_agg.consumption_aggregated[t] - m_agg.DISCHARGE_PHYS[t] )*step_duration   
            else:
                return m_agg.LEVEL[t] == m_agg.LEVEL[pd.Timestamp(t) - 
                                                 pd.Timedelta(pd.infer_freq(index))] + (
                    m_agg.CHARGE[t] - m_agg.consumption_aggregated[t] - m_agg.DISCHARGE_PHYS[t]) * step_duration 
            
       
    m_agg.Recursive_level = pyo.Constraint(m_agg.t, rule = recursive_level)
    
    def level_constraint(m_agg, t):
        if model_type=="ees":
            return m_agg.LEVEL[t] >= m_agg.ees_min[t] 
        else:
            return m_agg.LEVEL[t] <= aggregated_max_battery
    m_agg.Level_constraint = pyo.Constraint(m_agg.t, rule=level_constraint)
    
    def level_constraint_2(m_agg, t):
        if model_type=="ees":
            return m_agg.LEVEL[t] <= 0
        else:
            return m_agg.LEVEL[t] >= 0
    m_agg.Level_constraint_2 = pyo.Constraint(m_agg.t, rule=level_constraint_2)
    
    #if (model_type == "naive")  & (flex=="constrained"): ####
     #   dep_index = consumption_aggregated[(consumption_aggregated==0) & (consumption_aggregated.shift(-1) > 0) == True].index
      #  m_agg.t_dep = pyo.Set(initialize = dep_index, ordered = True)

      #  def full_before_next_trip(m_agg, t_dep):
       #     return m_agg.LEVEL[t_dep] >= uncontrolled_level_accurate[dep_index].loc[t_dep]
        #m_agg.Full_before_next_trip = pyo.Constraint(m_agg.t_dep, rule=full_before_next_trip)
                    
    def power_discharge_phys_max(m_agg, t):
        if V2G == True:
            return m_agg.DISCHARGE_PHYS[t] <= m_agg.neg_power[t] 
        else: 
            return m_agg.DISCHARGE_PHYS[t] == 0
    m_agg.Power_discharge_phys_max = pyo.Constraint(m_agg.t, rule=power_discharge_phys_max)

    if model_type == "ees":
        def power_charge_max(m_agg, t):
            return m_agg.CHARGE[t] <= m_agg.power[t] - m_agg.uncontrolled_charge[t] 
        
        def power_discharge_consumption_max(m_agg, t):
                return m_agg.DISCHARGE_WAIT[t] <=  m_agg.uncontrolled_charge[t] 
        m_agg.Power_discharge_consumption_max = pyo.Constraint(m_agg.t, rule=power_discharge_consumption_max)
    else:
        def power_charge_max(m_agg, t):
            return m_agg.CHARGE[t] <= m_agg.power[t]   
    m_agg.Power_charge_max = pyo.Constraint(m_agg.t, rule=power_charge_max)
    
    # objective function
    if model_type == "ees":
        def min_ees_costs(m_agg): 
            return sum(
                (m_agg.CHARGE[t]-m_agg.DISCHARGE_WAIT[t]-m_agg.DISCHARGE_PHYS[t]
                ) * prices[t] *step_duration 
                for t in m_agg.t
            ) 
        m_agg.Obj_min_ees_costs = pyo.Objective(rule=min_ees_costs, sense=pyo.minimize)
    else:
        def min_naive_costs(m_agg): 
            return sum(
                (m_agg.CHARGE[t] - m_agg.DISCHARGE_PHYS[t]) * prices[t] *step_duration 
                for t in m_agg.t
            ) 
        m_agg.Obj_min_naive_costs = pyo.Objective(rule=min_naive_costs, sense=pyo.minimize)
        
    #find solver
    solvername='glpk'

    #prepare solver
    optimizer = opt.SolverFactory(solvername) 
    solved_model = optimizer.solve(m_agg, tee=True)        
    
    agg_solutions[model_type] = {}
    agg_solutions[model_type]["costs"] = solved_model['Problem']()['Lower bound']
    agg_solutions[model_type]["CHARGE"] = pd.DataFrame.from_dict(m_agg.CHARGE.extract_values(), orient='index', columns = [model_type])
    if model_type == "ees":
        agg_solutions[model_type]["DISCHARGE"] = pd.DataFrame.from_dict(m_agg.DISCHARGE_WAIT.extract_values(), orient='index', columns = [model_type]) + pd.DataFrame.from_dict(m_agg.DISCHARGE_PHYS.extract_values(), orient='index', columns = [model_type])
    else:
        agg_solutions[model_type]["DISCHARGE"] = pd.DataFrame.from_dict(m_agg.DISCHARGE_PHYS.extract_values(), orient='index', columns = [model_type])
    agg_solutions[model_type]["LEVEL"] = pd.DataFrame.from_dict(m_agg.LEVEL.extract_values(), orient='index', columns = [model_type])

# %% [markdown]
# def plot_aggregated_results(model_type):
#     obversvations = 100#len(ees_constraints_aggergated)
#     x = level_index[10:obversvations]
#     fig, ax = plt.subplots(3)
#     ax[0].step(x,
#                pyo.value(agg_solutions[model_type]["CHARGE"].values[10:obversvations]), where="pre")
#     ax[0].set_title("{}_charging".format(model_type))
#
#
#     ax[1].step(x,
#                pyo.value(agg_solutions[model_type]["DISCHARGE"].values[10:obversvations]), where="pre")
#     ax[1].set_title("{}_discharging".format(model_type))
#
#
#     ax[2].plot(x,
#                pyo.value(agg_solutions[model_type]["LEVEL"].values[10:obversvations]))
#     ax[2].set_title("{}_level".format(model_type))
#     ax[2].set_ylabel("kWh")
#
#
#     for i in range(0,2):
#         ax[i].set_ylabel("kWh/15min")
#         ax[i].set_xticks(pd.date_range(x[0], x[-1], freq="D"))
#         #plt.set_xticklabels(rotation= 45)
#         plt.xticks(rotation= 45)
#     fig.autofmt_xdate(rotation=45)
#
#
#     plt.tight_layout()
#     plt.show()
#
# plot_aggregated_results("ees")
# plot_aggregated_results("naive")

# %% [markdown]
# # Analysis

# %%
agg_overest_solutions = {}

for model_type in ["m_early_agg", "m_late_agg"]:
    #Initialize model
    m_agg = pyo.ConcreteModel()

    #initialize sets
    m_agg.t = pyo.Set(initialize = ees_constraints_aggergated.index, ordered = True)

    m_agg.consumption_aggregated = pyo.Param(m_agg.t, initialize=consumption_aggregated.to_dict())
    m_agg.power = pyo.Param(m_agg.t, initialize=power_aggregated.to_dict()) 
    m_agg.neg_power = pyo.Param(m_agg.t, initialize=neg_power_aggregated.to_dict()) 

    m_agg.LEVEL = pyo.Var(m_agg.t, within = pyo.NonNegativeReals, bounds=(
        0, aggregated_max_battery))
    m_agg.CHARGE = pyo.Var(m_agg.t, within = pyo.NonNegativeReals)
    m_agg.DISCHARGE = pyo.Var(m_agg.t, within = pyo.NonNegativeReals)
    
    if (model_type == "m_late_agg")  & (flex=="constrained"): ###
        dep_index = consumption_aggregated[(consumption_aggregated==0) & (consumption_aggregated.shift(-1) > 0) == True].index
        m_agg.t_dep = pyo.Set(initialize = dep_index, ordered = True)
        def full_before_next_trip(m_agg, t_dep):
            return m_agg.LEVEL[t_dep] >= uncontrolled_level_accurate[dep_index].loc[t_dep]
        ###m_agg.Full_before_next_trip = pyo.Constraint(m_agg.t_dep, rule=full_before_next_trip)
        
        
    #level constraints
    def recursive_level(m_agg, t):
        if t == level_index[0]:
            return m_agg.LEVEL[t] == level_0_agg + m_agg.CHARGE[t] - m_agg.consumption_aggregated[t]
        else:    
            return m_agg.LEVEL[t] == m_agg.LEVEL[pd.Timestamp(t) - 
                                             pd.Timedelta("1h")] + (
                m_agg.CHARGE[t] - m_agg.consumption_aggregated[t] - m_agg.DISCHARGE[t] )
    m_agg.Recursive_level = pyo.Constraint(m_agg.t, rule = recursive_level)
    
    def final_level(m_agg, t):
        if t == index[-1]:
            return m_agg.LEVEL[t] == level_T_agg
        else: 
            return pyo.Constraint.Skip
    m_agg.Final_level = pyo.Constraint(m_agg.t, rule=final_level)
    
    #bidirectional charging 
    def neg_power_min(m_agg, t):
        if V2G == True:
            return m_agg.DISCHARGE[t] <= m_agg.neg_power[t]
        else: 
            return m_agg.DISCHARGE[t] == 0
    m_agg.Neg_power_min_restriction = pyo.Constraint(m_agg.t, rule=neg_power_min)

    def power_max(m_agg, t):
        return m_agg.CHARGE[t] <= m_agg.power[t]   
    m_agg.Power_max_restriction = pyo.Constraint(m_agg.t, rule=power_max)
    
    def final_level(m_agg, t):
        if t == index[-1]:
            return m_agg.LEVEL[t] == level_T_agg
        else: 
            return pyo.Constraint.Skip
    m_agg.Final_level = pyo.Constraint(m_agg.t, rule=final_level)

    # objective function late
    def battery_level_sum(m_agg, t): 
        return sum(m_agg.LEVEL[t] for t in m_agg.t) 
    if model_type == "m_late_agg":
        sense = pyo.minimize
    elif model_type == "m_early_agg":
        sense = pyo.maximize     
    m_agg.Obj = pyo.Objective(rule=battery_level_sum, sense=sense)

    #find solver
    solvername='glpk'

    #prepare solver
    optimizer = opt.SolverFactory(solvername) 
    solved_model = optimizer.solve(m_agg, tee=True)        

    #store data in dictionary
    agg_overest_solutions[model_type] = pd.DataFrame.from_dict(
        m_agg.LEVEL.extract_values(), orient='index')[0]
# Out:
# WARNING: Implicitly replacing the Component attribute Final_level (type=<class
#     'pyomo.core.base.constraint.IndexedConstraint'>) on block unknown with a
#     new Component (type=<class
#     'pyomo.core.base.constraint.IndexedConstraint'>). This is usually
#     indicative of a modelling error. To avoid this warning, use
#     block.del_component() and block.add_component().
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmp3q_opixh.glpk.raw
#  --wglp /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmp4vfg3brs.glpk.glp
#  --cpxlp /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmpvpimvce1.pyomo.lp
# Reading problem data from '/var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmpvpimvce1.pyomo.lp'...
# 3005 rows, 3004 columns, 6006 non-zeros
# 19033 lines were read
# Writing problem data to '/var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmp4vfg3brs.glpk.glp'...
# 16021 lines were written
# GLPK Simplex Optimizer 5.0
# 3005 rows, 3004 columns, 6006 non-zeros
# Preprocessing...
# 995 rows, 996 columns, 1990 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 995
#       0: obj =   2.574042158e+06 inf =   6.251e+05 (2)
#     119: obj =   2.332254725e+07 inf =   0.000e+00 (0)
# *  1991: obj =   3.773481912e+08 inf =   0.000e+00 (0) 14
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 2.7 Mb (2801320 bytes)
# Writing basic solution to '/var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmp3q_opixh.glpk.raw'...
# 6018 lines were written
# WARNING: Implicitly replacing the Component attribute Final_level (type=<class
#     'pyomo.core.base.constraint.IndexedConstraint'>) on block unknown with a
#     new Component (type=<class
#     'pyomo.core.base.constraint.IndexedConstraint'>). This is usually
#     indicative of a modelling error. To avoid this warning, use
#     block.del_component() and block.add_component().
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmp3xbtxqm1.glpk.raw
#  --wglp /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmpd05b2h1s.glpk.glp
#  --cpxlp /var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmpwvi28koi.pyomo.lp
# Reading problem data from '/var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmpwvi28koi.pyomo.lp'...
# 3005 rows, 3004 columns, 6006 non-zeros
# 19033 lines were read
# Writing problem data to '/var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmpd05b2h1s.glpk.glp'...
# 16021 lines were written
# GLPK Simplex Optimizer 5.0
# 3005 rows, 3004 columns, 6006 non-zeros
# Preprocessing...
# 995 rows, 996 columns, 1990 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 995
#       0: obj =   2.574042158e+06 inf =   6.251e+05 (2)
#     119: obj =   2.332254725e+07 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 2.7 Mb (2801320 bytes)
# Writing basic solution to '/var/folders/xb/lfd6_z7178g_6zv_ygw5vd4m0000gp/T/tmp3xbtxqm1.glpk.raw'...
# 6018 lines were written

# %%
#power
#naive
neg_power_aggregated.mean()
power_aggregated.mean()

#EES
(neg_power_aggregated+uncontrolled_charge_accurate).mean()
(power_aggregated-uncontrolled_charge_accurate).mean()

# %%
#overestimation in kWh how much could be shifted from uncontrolled charging?
overestimation_dict = {}

overestimation = 1 + (
    (agg_overest_solutions["m_late_agg"] - agg_overest_solutions["m_early_agg"]).sum()
    - ees_constraints_aggergated.sum()
) / ees_constraints_aggergated.sum()

print(
    "potential overestimation factor: " + str(
        overestimation) + " : " + str((
    (agg_overest_solutions["m_late_agg"] - agg_overest_solutions["m_early_agg"]).sum()
    - ees_constraints_aggergated.sum()
) / ees_constraints_aggergated.sum()*100) + " %"
)
                                                  
overestimation_dict[f'profiles: {profiles}, steps: {time_steps}'] =  overestimation

# %% [markdown]
# #df = pd.DataFrame().from_dict(overestimation_dict, orient="index")
# df_profiles = df.iloc[:7]
# df_profiles.index = [int(
#     i.split(":")[1].split(",")[0]
# )
#  for i in df_profiles.index]
#
# df_profiles.to_pickle("profiles_overestimation")
# df_profiles.plot()
# plt.legend(["time_steps: 673"])
#
# df_time_steps = df.iloc[7:]
# df_time_steps.index = [int(
#     i.split(",")[1].split(":")[1]
# )
#  for i in df_time_steps.index]
#
# df_time_steps.to_pickle("time_step_overestimation")
# df_time_steps.plot()
# plt.legend(["profiles: 3311"])

# %%
keys=["naive aggregation", "virtual storage \n approache"]

# %%
overestimated = (agg_overest_solutions["m_early_agg"] - agg_overest_solutions["m_late_agg"])


ts = pd.concat([
     overestimated, -ees_constraints_aggergated
], axis = 1, keys = keys)*scale

ax = ts.plot(ylabel="Flexibility potential [GWh]", color = ["blue", "orange"])

#ax.legend(bbox_to_anchor=(0.98,0.2))

ax2 = ax.twinx()
ax2.spines['right'].set_position(('axes',  1))

ts_2 = pd.Series(100,level_index)
ax2 = ts_2.plot(alpha=0, ylabel="%")

n = round(ts.loc[ts.index[1:], keys[1]].max())
#ax.axhline(n, color="black", alpha = 1, linewidth=0.8)
#ax.text(y=n+20,x=t[-200], s=f"< {n} GWh,  {round(n/ts.max().max(), 2)*100}%")

ax.set_ylim(0), ax2.set_ylim(0)


ax.grid('on', which='minor', axis='x', alpha=0.3)
ax.grid('on', which='major' )

max_val = 100 - int(overestimated.max()*scale) % 100 + int(overestimated.max()*scale)

ax.legend(bbox_to_anchor=(1.1, 1))


for i, s in enumerate([ts, ts_2]):
    if i == 0: 
        step_size = (max_val)/5 
        ax.set_ylim(0, max_val)
        ax.set_yticks(np.arange(0,max_val+1, step_size))
    else:
        step_size = 100/5
        ax2.set_ylim(0, 110)
        ax2.set_yticks(np.arange(0,109, step_size))

plt.savefig('level_comparison_size_ts.png', bbox_inches = "tight")

# %%
#ts_no_level = ts[keys[1]]
#ts_no_charge = ts[keys[1]]
#ts_pub = ts[keys[1]]

# %%
#df_no_pub = df
condition = (ts.index.week > 1)&(ts.index.week < 4)
df = ts[keys[1]][condition]#/scale/fleet_size

fig, ax = plt.subplots(figsize=(8, 3.5))
ax.plot(df.index, df,  color = "orange")
ax.xaxis.set_major_locator(mdates.DayLocator(interval = 1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))

ax.set_ylabel("Flexibility potential [kWh/EV]")
ax.grid('on', which='minor', axis='x', alpha=0.3)
ax.grid('on', which='major' )
ax.set_xlabel("First week of February, 2020")
ax.set_xlim(df.index[0],df.index[-1])
ax.set_ylim(0)
plt.savefig('ees_1_week.png', bbox_inches = "tight")
# Out:
# /Users/Jarusch/opt/anaconda3/envs/emobpyenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)

# %%
df.mean()

# %%
df = pd.concat([df_yes_pub, df_no_pub], axis=1, keys=["full potential", "constrained potential"])

# %%
# df_yes_pub = df
condition = (ts.index.week > 1)&(ts.index.week < 4)
#df = ts[keys[1]][condition]/df_con.shape[1]#[condition]

fig, ax = plt.subplots(figsize=(8, 3.5))
ax.plot(df.index, df)#,  color = "orange")
ax.xaxis.set_major_locator(mdates.DayLocator(interval = 1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))
ax.legend(list(df.columns))

ax.set_ylabel("Flexibility potential [GWh]")
ax.grid('on', which='minor', axis='x', alpha=0.3)
ax.grid('on', which='major' )
ax.set_xlabel("First week of February, 2020")
ax.set_xlim(df.index[0],df.index[-1])
ax.set_ylim(0)
plt.savefig('ees_1_week_comparison.png', bbox_inches = "tight")

# %%
# df_yes_pub = df
condition = (ts.index.week > 1)&(ts.index.week < 4)
df = ts[keys[1]][condition]/df_con.shape[1]#[condition]

fig, ax = plt.subplots(figsize=(8, 3.5))
ax.plot(df.index, df,  color = "orange")
ax.xaxis.set_major_locator(mdates.DayLocator(interval = 1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))

ax.set_ylabel("Flexibility potential [GWh]")
ax.grid('on', which='minor', axis='x', alpha=0.3)
ax.grid('on', which='major' )
ax.set_xlabel("First week of February, 2020")
#ax.set_xlim(df.index[0],df.index[-1])
ax.set_ylim(0)
plt.savefig('ees_1_week.png', bbox_inches = "tight")

# %%
ts.mean()

# %%
 -ees_constraints_aggergated.mean()*scale

# %%
(ts.apply(lambda r: (r["naive"]-r["ees"])/r["naive"], axis=1)*100).describe()

# %%
ees = -ees_constraints_aggergated.mean()
naive = (agg_overest_solutions["m_early_agg"] - agg_overest_solutions["m_late_agg"]).mean()
ts = pd.DataFrame([
    naive, ees],
    ["naive", "ees"])*scale

ax = ts.plot.bar(rot=0, legend=False )
ax.plot(["naive", "ees"], [ees_sum, ees_sum])

ax.set_ylabel("average fleet solution space [TWh/day]")

ax2 = ax.twinx()

ax2.spines['right'].set_position(('axes',  1))


max_val = 10 - int(ts.max()) % 10 + int(ts.max())

for i, s in enumerate([ts, ts_2]):
    if i == 0: 
        step_size = (max_val)/5 
        ax.set_ylim(0, max_val+step_size/5)
        ax.set_yticks(np.arange(0, max_val+1, step_size))
    else:
        step_size = 100/5
        ax2.set_ylim(0, 100 +step_size/5)
        ax2.set_yticks(np.arange(0,101, step_size))

e = ts.loc["ees"].max()
n = ts.loc["naive"].max()
ax2.text(0.75, 4, f"{round(e)} GWh, {round(e/n, 2)*100}%")

#plt.savefig(os.path.join(pics,'level_comparison_size_bar.png'), bbox_inches = "tight")

# %%
#controlled charging (physical) = uncontrolled charging - ees_dis + ee_scharging
#fig, ax = plt.subplots()

retransformed_ees_level = pd.concat([
    uncontrolled_level_accurate, agg_solutions["ees"]["LEVEL"]
], axis=1).sum(1)
retransformed_ees_level.name = "retransformed_ees"

ax = (pd.concat([
    retransformed_ees_level, agg_solutions["naive"]["LEVEL"]
], axis=1)*10**-3).plot(ylabel="aggregated level [GWh]", ylim=0)

#.loc[level_index.day <= 7]
ax.grid('on', which='minor', axis='x' )
ax.grid('on', which='major' )

plt.legend(bbox_to_anchor=(1.0, 1.0))


#fig.tight_layout()
#plt.savefig(os.path.join(pics, price_mode,'opt_level_comparison_long.png'), bbox_inches = "tight")#week

# %%
ax = (pd.concat([
    uncontrolled_level_accurate, retransformed_ees_level, -agg_solutions["ees"]["LEVEL"]
], axis=1)*10**-3).plot(ylabel="aggregated level [GWh]", ylim=0)

ax.grid('on', which='minor', axis='x' )

ax.grid('on', which='major' )

plt.legend(bbox_to_anchor=(1.0, 1.0))

#plt.savefig(os.path.join(pics, price_mode,'shifted_energy.png'), bbox_inches = "tight") #long, week, day_3

# %%
-agg_solutions["ees"]["LEVEL"].sum()*10**-6

# %%
#controlled charging (physical) = uncontrolled charging - ees_dis + ee_scharging

retransformed_ees_charge = pd.concat([
    uncontrolled_charge_accurate.loc[level_index[1:]], agg_solutions["ees"]["CHARGE"], - agg_solutions["ees"]["DISCHARGE"]
], axis=1).sum(1)

charge_list = [agg_solutions["naive"]["CHARGE"]]
if V2G==True: charge_list.append(- agg_solutions["naive"]["DISCHARGE"])
naive_dis_charge = pd.concat(charge_list, axis=1).sum(1)

retransformed_ees_charge.name, naive_dis_charge.name = "retransformed_ees", "naive"

df_list = [uncontrolled_charge_accurate, retransformed_ees_charge, naive_dis_charge]
df_list = [df*10**-3 for df in df_list]
ax = pd.concat(df_list, axis=1).plot(ylabel="charging [GW]", ylim=(0))
ax.grid('on', which='minor', axis='x' )
ax.grid('on', which='major' )
#.loc[level_index.day <= 7]
plt.legend(bbox_to_anchor=(1.0, 1.0))

#plt.savefig(os.path.join(pics, price_mode,'all_charging.png'), bbox_inches = "tight") #long, week, day_3

# %%
    fig, ax = plt.subplots(figsize=(8, 3.5))

ts =  (pd.concat([
    uncontrolled_charge_accurate, agg_solutions["ees"]["CHARGE"]-agg_solutions["ees"]["DISCHARGE"]
], axis=1)*10**-3).resample("h").mean()


ax.step(ts.index, ts, where="post")
ax.set_ylabel("GW")
ax.set_xlabel("January; 2020")
ax.set_ylim(-10,80)
plt.axhline(y=0)
ax.xaxis.set_major_locator(mdates.DayLocator(interval = 1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d'))

ax.legend(["uncontrolled", "ees: difference from uncontrolled"], bbox_to_anchor=(1.0, 1.0))

plt.grid()

#plt.savefig(os.path.join(pics, 'shifted_charge.png'), bbox_inches = "tight")

# %%
#plausibility: charging the same in all strategies? 
pd.concat([
    uncontrolled_charge_accurate, retransformed_ees_charge, naive_dis_charge.iloc[1:]
], axis=1).sum(0)

# %%
pd.concat([retransformed_ees_level, agg_solutions["naive"]["LEVEL"]], axis=1).iloc[-1]

# %% [markdown]
# ## Cost

# %%
uncontrolled_costs = sum([
    uncontrolled_charge_accurate[i] * prices[i] for i in index
])
controlled_costs_ees = sum([
    retransformed_ees_charge[i] * prices[i] for i in index
])
controlled_costs_naive = sum([
    naive_dis_charge[i] * prices[i] for i in index
])

# %%
#costs
fig, ax = plt.subplots()

plt.bar(x = ["uncontrolled", "controlled_ees", "controlled_naive"],  height=[
    uncontrolled_costs, controlled_costs_ees, controlled_costs_naive
])
plt.ylabel("costs for charging [€/year]")
plt.show()

fig.tight_layout()
#plt.savefig(os.path.join(pics, price_mode,'costs.pdf'),  bbox_inches = "tight")

# %%
ax = pd.DataFrame([
    (controlled_costs_ees-uncontrolled_costs)/(controlled_costs_naive-uncontrolled_costs), 1
], ["controlled_ees", "controlled_naive"]).plot.bar(rot=0, legend=False )


ax.set_ylabel("cost benefit: ees/naive [-]")


#plt.savefig(os.path.join(pics, price_mode,'costs_percent.png'), bbox_inches = "tight")

# %% [markdown]
# ## Scaling

# %%
fleeet_size = 10**6

# %%
costs = pd.DataFrame()
solution_space = pd.DataFrame()
solution_space['ees_0'] = -ees_constraints_aggergated*10**-3

solution_space_bar = pd.DataFrame()
costs = pd.DataFrame([
    controlled_costs_ees
], ["0"])

soc_min_list =  [ "0.1", "0.2", "0.3"]

for s in soc_min_list:#"0",
    raw = pd.read_pickle(f"solution_spaces_ts_{s}").rename(columns= {"ees":f"ees_{s}"})
    solution_space = pd.concat([solution_space, raw[f"ees_{s}"]], axis = 1)
    ts = pd.read_pickle(f"costs_{s}").rename(columns= {0:f"{s}"}).iloc[0]
    costs= pd.concat([costs, ts], axis = 0)
    
solution_space['naive'] = raw ["naive"]
solution_space_bar = solution_space.sum(0) 


soc_min_list.insert(0,"0")

# %%
costs.loc["naive"] = controlled_costs_naive

# %%
ax = (costs/1000).plot.bar(rot=0, legend=False)
ax.set_ylabel("costs for charging [1,000€/year]")


ax2.set_ylim(0,100)


plt.savefig(os.path.join(pics, 'costs_soc_min.png'), bbox_inches = "tight")

# %%
ts = solution_space

ax = ts.plot(ylabel="(virtual) GWh")
ax.legend(bbox_to_anchor=(1.1,1))


ax2 = ax.twinx()
ax2.spines['right'].set_position(('axes',  1))

ts_2 = pd.Series(100,level_index)
ax2 = ts_2.plot(alpha=0, ylabel="%")


ax.set_ylim(0), ax2.set_ylim(0)


ax.grid('on', which='minor', axis='x' )
ax.grid('on', which='major' )

for i, s in enumerate([ts, ts_2]):
    if i == 0: 
        ax.set_ylim(0, 550)
        step_size = (500)/5
        ax.set_yticks(np.arange(0, 550, step_size))
    else:
        ax2.set_ylim(0, 110)
        step_size = 100/5
        ax2.set_yticks(np.arange(0,110, step_size))


plt.savefig(os.path.join(pics, 'level_comparison_soc_min_ts.png'))

# %%
ts = solution_space_bar*10**-3

ax = ts.plot.bar(rot=0, legend=False )


ax.set_ylabel("solution space size [GWh]")

ax2 = ax.twinx()

ax2.spines['right'].set_position(('axes',  1))

ax.set_ylim(0 , 330)
step_size = (300)/5
ax.set_yticks(np.arange(0,330, step_size))
 
ax2.set_ylim(0, 110)
step_size = 100/5
ax2.set_yticks(np.arange(0,110, step_size))
ax2.set_ylabel("%")


ax.grid('on', which='minor', axis='x' )

plt.savefig(os.path.join(pics,'level_comparison_size_bar.png'), bbox_inches = "tight")

# %%
overestimation_factors = pd.Series( [1.7689430340159902, 1.8651748933840055, 1.9937007078507452, 2.1678926919803545],  solution_space_bar[:-1].index
                                )

overestimation_factors.plot.bar(rot=0)

plt.savefig(os.path.join(pics,'level_comparison_size_bar.png'), bbox_inches = "tight")
